# %%
import pickle
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt  
import numpy as np 
import cartopy 
import cartopy.crs as ccrs
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from eod import trmm

# %%
test_dir = '/users/global/cornkle/data/pythonWorkspace/proj_CEH/eod/tests/test_files/trmm'
#test_dir = '/users/global/cornkle/data/OBS/TRMM/trmm_swaths_WA'
#obj.fpaths[1001] #[-10,10,7,14]

# %%
area=[-15, 10, 15, 20]
obj=trmm.ReadWA(test_dir, area=area)#, area=area)
obj.fpaths
# Out:
# ['/users/global/cornkle/data/pythonWorkspace/proj_CEH/eod/tests/test_files/trmm/2007/08/2A25.20070816.55562.7.gra',
#  '/users/global/cornkle/data/pythonWorkspace/proj_CEH/eod/tests/test_files/trmm/2007/08/2A25.20070817.55577.7.gra']

# %%
d=obj.get_data(obj.fpaths[0])

# %%
print(dd.values[...,None].shape)
dd.values.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-5a46b180a926> in <module>()
# ----> 1 print(dd.values[...,None].shape)
#       2 dd.values.shape
#
# TypeError: 'method' object is not subscriptable

# %%
da = xr.DataArray(dd[...,None], coords={'lat':(('y', 'x'), dd['lat'].values), 'lon':(('y', 'x'), dd['lon'].values)}, dims=['y', 'x'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /users/global/cornkle/miniconda3/lib/python3.5/site-packages/xarray/core/dataset.py in _construct_dataarray(self, name)
#     466         try:
# --> 467             variable = self._variables[name]
#     468         except KeyError:
#
# KeyError: (Ellipsis, None)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-04b0c65f1eea> in <module>()
# ----> 1 da = xr.DataArray(dd[...,None], coords={'lat':(('y', 'x'), dd['lat'].values), 'lon':(('y', 'x'), dd['lon'].values)}, dims=['y', 'x'])
#
# /users/global/cornkle/miniconda3/lib/python3.5/site-packages/xarray/core/dataset.py in __getitem__(self, key)
#     518
#     519         if hashable(key):
# --> 520             return self._construct_dataarray(key)
#     521         else:
#     522             return self._copy_listed(np.asarray(key))
#
# /users/global/cornkle/miniconda3/lib/python3.5/site-packages/xarray/core/dataset.py in _construct_dataarray(self, name)
#     467             variable = self._variables[name]
#     468         except KeyError:
# --> 469             _, name, variable = _get_virtual_variable(self._variables, name)
#     470
#     471         coords = OrderedDict()
#
# /users/global/cornkle/miniconda3/lib/python3.5/site-packages/xarray/core/dataset.py in _get_virtual_variable(variables, key)
#      39     """
#      40     if not isinstance(key, basestring):
# ---> 41         raise KeyError(key)
#      42
#      43     split_key = key.split('.', 1)
#
# KeyError: (Ellipsis, None)

# %%
d['p'][...,]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a050daed4fba> in <module>()
# ----> 1 d['p'][...,]
#
# NameError: name 'd' is not defined

# %%
time=[2006]
da = xr.DataArray(d['p'], coords={'lat':(('y', 'x'), d['lat']), 'lon':(('y', 'x'), d['lon'])}, dims=['y', 'x'])

# %%
ax = plt.axes(projection=ccrs.PlateCarree())
da.plot.pcolormesh(ax=ax, transform=ccrs.PlateCarree(), x='lon', y='lat')
ax.coastlines(); 
# Gridlines
xl = ax.gridlines(draw_labels=True);
xl.xlabels_top = False
xl.ylabels_right = False
# Countries
ax.add_feature(cartopy.feature.BORDERS, linestyle='--');
