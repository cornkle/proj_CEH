# %%
import xarray as xr
from saveCore_standalone_NFLICS import run_powerBlobs, powerBlob_utils, util
import ccores.cores as cores
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
import os
from utils import u_darrays as uda
from eod import msg_panAfrica
from utils import u_grid, u_interpolate as u_int
import glob
from utils import constants as cnst
import ipdb

# %%
cd ..
# Out:
# /home/ck/pythonWorkspace/proj_CEH

# %%
msg_obj = msg_panAfrica.ReadMsg(cnst.other_drive+'nflics/SSA_data/', y1=2010, y2=2010, months=[11])

# %%
#lls = [-21, 45, -33.2, 26]
#lls = [8, 42, -35, 0]
#lls = [-20, 42, -36, 25]\\
lls = [-25, 55, -38, 26]

# %%
msg_obj.set_date(2010,11,4,19,0)

# %%
msg_obj.fpath
# Out:
# ['/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010000.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010015.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010030.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010045.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010100.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010115.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010130.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010145.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010200.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010215.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010230.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010245.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010300.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010315.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010330.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010345.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010400.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010415.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010430.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010445.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010500.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010515.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010530.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010545.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010600.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010615.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010630.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010645.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010700.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010715.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010730.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010745.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010800.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010815.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010830.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010845.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010900.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010915.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010930.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011010945.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011000.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011015.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011030.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011045.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011100.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011115.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011130.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011145.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011200.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011215.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011230.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011245.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011300.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011315.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011330.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011345.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011400.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011415.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011430.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011445.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011500.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011515.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011530.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011545.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011600.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011615.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011630.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011645.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011700.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011715.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011730.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011745.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011800.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011815.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011830.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011845.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011900.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011915.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011930.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011011945.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011012000.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011012015.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011012030.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011012045.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011012100.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011012115.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011012130.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011012145.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011012200.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011012215.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011012230.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011012245.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011012300.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011012315.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011012330.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011012345.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020000.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020015.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020030.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020045.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020100.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020115.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020130.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020145.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020200.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020215.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020230.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020245.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020300.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020315.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020330.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020345.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020400.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020415.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020430.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020445.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020500.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020515.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020530.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020545.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020600.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020615.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020630.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020645.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020700.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020715.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020730.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020745.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020800.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020815.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020830.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020845.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020900.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020915.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020930.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011020945.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021000.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021015.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021030.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021045.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021100.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021115.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021130.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021145.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021200.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021215.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021230.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021245.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021300.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021315.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021330.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021345.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021400.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021415.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021430.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021445.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021500.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021515.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021530.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021545.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021600.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021615.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021630.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021645.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021700.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021715.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021730.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021745.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021800.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021815.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021830.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021845.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021900.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021915.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021930.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011021945.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011022000.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011022015.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011022030.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011022045.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011022100.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011022115.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011022130.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011022145.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011022200.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011022215.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011022230.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011022245.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011022300.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011022315.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011022330.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011022345.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030000.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030015.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030030.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030045.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030100.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030130.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030145.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030200.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030215.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030230.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030245.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030300.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030315.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030330.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030345.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030400.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030415.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030430.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030445.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030500.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030515.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030530.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030545.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030600.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030615.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030630.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030645.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030700.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030715.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030730.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030745.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030800.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030815.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030830.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030845.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030900.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030915.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030930.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011030945.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031000.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031015.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031030.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031045.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031100.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031115.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031130.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031145.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031200.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031215.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031230.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031245.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031300.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031315.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031330.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031345.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031400.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031415.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031430.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031445.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031500.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031515.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031530.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031545.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031600.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031615.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031630.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031645.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031700.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031715.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031730.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031745.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031800.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031845.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031900.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031915.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031930.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011031945.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011032000.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011032015.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011032030.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011032045.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011032100.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011032115.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011032130.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011032145.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011032200.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011032215.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011032230.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011032245.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011032300.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011032315.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011032330.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011032345.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040000.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040015.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040030.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040045.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040100.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040115.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040130.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040145.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040200.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040215.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040230.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040245.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040300.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040315.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040330.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040345.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040400.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040415.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040430.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040445.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040500.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040515.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040530.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040545.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040600.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040615.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040630.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040645.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040700.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040715.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040730.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040745.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040800.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040815.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040830.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040845.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040900.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040915.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040930.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011040945.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041000.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041015.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041030.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041045.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041100.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041115.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041130.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041145.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041200.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041215.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041230.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041245.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041300.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041315.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041330.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041345.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041400.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041415.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041430.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041445.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041500.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041515.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041530.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041545.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041600.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041615.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041630.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041645.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041700.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041715.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041730.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041745.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041800.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041815.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041830.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041845.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041900.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041915.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041930.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011041945.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011042000.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011042015.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011042030.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011042045.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011042100.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011042115.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011042130.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011042145.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011042200.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011042215.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011042230.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011042245.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011042300.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011042315.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011042330.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011042345.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050000.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050015.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050030.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050045.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050100.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050115.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050130.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050145.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050200.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050215.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050230.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050245.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050300.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050315.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050330.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050345.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050400.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050415.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050430.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050445.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050500.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050515.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050530.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050545.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050600.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050615.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050630.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050645.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050700.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050715.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050730.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050745.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050800.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050815.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050830.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050845.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050900.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050915.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050930.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011050945.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051000.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051015.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051030.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051045.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051100.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051115.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051130.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051145.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051200.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051215.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051230.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051245.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051300.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051315.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051330.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051345.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051400.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051415.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051430.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051445.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051500.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051515.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051530.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051545.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051600.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051615.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051630.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051645.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051700.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051715.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051730.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051745.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051800.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051815.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051830.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051845.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051900.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051915.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051930.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011051945.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011052000.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011052015.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011052030.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011052045.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011052100.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011052115.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011052130.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011052145.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011052200.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011052215.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011052230.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011052245.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011052300.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011052315.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011052330.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011052345.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060000.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060015.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060030.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060045.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060100.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060115.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060130.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060145.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060200.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060215.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060230.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060245.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060300.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060315.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060330.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060345.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060400.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060415.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060430.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060445.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060500.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060515.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060530.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060545.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060600.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060615.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060630.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060645.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060700.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060715.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060730.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060745.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060800.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060815.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060830.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060845.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060900.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060915.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060930.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011060945.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061000.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061015.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061030.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061045.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061100.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061115.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061130.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061145.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061200.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061215.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061230.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061245.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061300.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061315.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061330.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061345.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061400.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061415.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061430.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061445.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061500.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061515.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061530.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061545.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061600.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061615.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061630.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011061645.gra',
# ...
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011091330.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011091345.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011091400.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011091415.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011091430.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011091445.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011091500.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011091515.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011091530.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011091545.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011091600.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011091615.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011091630.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011091645.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011091700.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011091715.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011091730.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011091745.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011091800.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011091815.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011091830.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011091845.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011091900.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011091915.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011091930.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011091945.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011092000.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011092015.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011092030.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011092045.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011092100.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011092115.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011092130.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011092145.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011092200.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011092215.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011092230.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011092245.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011092300.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011092315.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011092330.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011092345.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100000.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100015.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100030.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100045.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100100.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100115.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100130.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100145.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100200.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100215.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100230.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100245.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100300.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100315.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100330.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100345.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100400.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100415.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100430.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100445.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100500.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100515.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100530.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100545.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100600.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100615.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100630.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100645.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100700.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100715.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100730.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100745.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100800.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100815.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100830.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100845.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100900.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100915.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100930.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011100945.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101000.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101015.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101030.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101045.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101100.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101115.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101130.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101145.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101200.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101215.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101230.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101245.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101300.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101315.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101330.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101345.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101400.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101415.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101430.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101445.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101500.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101515.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101530.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101545.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101600.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101615.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101630.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101645.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101700.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101715.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101730.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101745.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101800.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101815.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101830.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101845.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101900.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101915.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101930.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011101945.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011102000.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011102015.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011102030.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011102045.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011102100.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011102115.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011102130.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011102145.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011102200.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011102215.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011102230.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011102245.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011102300.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011102315.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011102330.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011102345.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110000.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110015.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110030.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110045.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110100.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110115.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110130.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110145.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110200.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110215.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110230.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110245.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110300.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110315.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110330.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110345.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110400.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110415.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110430.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110445.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110500.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110515.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110530.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110545.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110600.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110615.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110630.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110645.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110700.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110715.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110730.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110745.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110800.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110815.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110830.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110845.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110900.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110915.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110930.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011110945.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011111000.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011111015.gra',
#  '/media/ck/LStorage/global_water/other/nflics/SSA_data/ch9//2010/11/201011111030.gra',
#  ...]

# %%
from utils import u_gis

eq = []
south = []
scal = np.arange(0.1,2.5, 0.1)
for scales in scal:
    
    eq.append(u_gis.haversine(0,0,0+scales,0)[0])
    south.append(u_gis.haversine(0,-33, 0+scales, -33)[0])
    
f = plt.figure(figsize=(10,3), dpi=200)
ax = f.add_subplot(121)
ax.plot(scal*111, eq, label='zonal distance at 0S')
ax.plot(scal*111, south, label='zonal distance at 35S')
ax.set_ylabel('km')
ax.set_xlabel('assumed km')
plt.title('Deg distance in km')
plt.legend()


ax = f.add_subplot(122)
ax.plot(scal*111, np.array(south)-np.array(eq))
ax.set_ylabel('scale error (km)')
ax.set_xlabel('assumed km')

plt.title('Km scale error')


plt.tight_layout()

# %%
bigds = msg_obj.get_data()

# %%
bigds['t'].shape
# Out:
# (2080, 2268)

# %%
ds = bigds.where((bigds.lon >= lls[0]) & (bigds.lon <= lls[1]) & (bigds.lat >= lls[2]) & (bigds.lat <= lls[3]), drop=True)

# %%
ds['t'].shape
# Out:
# (2080, 2268)

# %%
# ipos = np.where((ds.lon >= lls[0]) & (ds.lon <= lls[1]) & (ds.lat >= lls[2]) & (ds.lat <= lls[3]))

# %%
bigds.lat.shape
# Out:
# (2080, 2268)

# %%
ds.lat.shape
# Out:
# (2080, 2268)

# %%
msg_full = xr.open_dataset('/home/ck/DIR/cornkle/data/ancils_python/MSG_000_LatLon.nc')#.where((msg_full.lon >= lls[0]) & (msg_full.lon <= lls[1]) & (msg_full.lat >= lls[2]) & (msg_full.lat <= lls[3]), drop=True)

# %%
msg_f = msg_full.rename({'south_north':'y', 'east_west':'x'})

# %%
msg_f = msg_f.where((msg_f.lon >= lls[0]) & (msg_f.lon <= lls[1]) & (msg_f.lat >= ds.lat.min()) & (msg_f.lat <= ds.lat.max()), drop=True)

# %%
msg_f.lat
# Out:
# <xarray.DataArray 'lat' (y: 2752, x: 2491)>
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=float32)
# Coordinates:
#     time     datetime64[ns] 2010-11-04T19:00:00
# Dimensions without coordinates: y, x
# Attributes:
#     standard_name:  Latitude

# %%
ds.lat
# Out:
# <xarray.DataArray 'lat' (y: 2080, x: 2268)>
# array([[ -37.558388,  -37.556046,  -37.553616, ..., -999.999   ,
#         -999.999   , -999.999   ],
#        [ -37.51846 ,  -37.516144,  -37.51369 , ..., -999.999   ,
#         -999.999   , -999.999   ],
#        [ -37.478493,  -37.476055,  -37.47351 , ..., -999.999   ,
#         -999.999   , -999.999   ],
#        ...,
#        [  24.833788,   24.83266 ,   24.831459, ...,   27.136353,
#           27.145126,   27.153954],
#        [  24.865915,   24.864788,   24.863512, ...,   27.1753  ,
#           27.184128,   27.193235],
#        [  24.898012,   24.896885,   24.895674, ...,   27.214367,
#           27.223099,   27.232262]], dtype=float32)
# Coordinates:
#     time     datetime64[ns] 2010-11-04T19:00:00
#     lat      (y, x) float32 -37.56 -37.56 -37.55 -37.55 ... 27.21 27.22 27.23
#     lon      (y, x) float32 -27.16 -27.12 -27.08 -27.03 ... 64.95 65.08 65.2
# Dimensions without coordinates: y, x

# %%
# subset = ds.isel(x=(ds.x>=ipos[1].min())&(ds.x<=ipos[1].max()), y=(ds.y>=ipos[0].min())&(ds.y<=ipos[0].max()))

# %%
np.unique(ds.lat)
# Out:
# array([-999.999   ,  -41.989723,  -41.81123 , ...,   27.214367,
#          27.223099,   27.232262], dtype=float32)

# %%
## a clean way of plotting - use matplotlib functions directly:
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy
def draw_map(ax, data, lon, lat, title=None,  mask_sig=None, quiver=None, contour=None, cbar_label=None, **kwargs):

    mapp = ax.contourf(lon, lat, data, transform=ccrs.PlateCarree(), **kwargs)  # this is the actual plot
    
    ## mask for significance indicator
    if mask_sig is not None:
         plt.contourf(lon, lat, mask_sig, colors='none', hatches='.',
                     levels=[0.5, 1], linewidth=0.1)
    
    ## quiver list
    if quiver is not None:
        qu = ax.quiver(quiver['x'], quiver['y'], quiver['u'], quiver['v'], scale=quiver['scale'])
    ## additional contour on plot   
    if contour is not None:
        ax.contour(contour['x'], contour['y'], contour['data'], levels=contour['levels'], cmap=contour['cmap'] )
        
    
    ax.coastlines()   ## adds coastlines
    # Gridlines
    xl = ax.gridlines(draw_labels=True);   # adds latlon grid lines
    xl.xlabels_top = False   ## labels off
    xl.ylabels_right = False
    plt.title(title)
    # Countries
 #   ax.add_feature(cartopy.feature.BORDERS, linestyle='--'); # adds country borders
    cbar = plt.colorbar(mapp)  # adds colorbar
    cbar.set_label(cbar_label)

# %%
f=plt.figure(figsize=(15,7))  # this opens a plot window
ax = f.add_subplot(111, projection=ccrs.PlateCarree())  # this opens a new plot axis
#draw_map(ax, ds['t'], ds.lon, ds.lat, levels=np.arange(-100,50), cmap='jet')
draw_map(ax, msg_full['lon'], msg_full.lon, msg_full.lat, cmap='jet', levels=np.arange(-25,60,1))
ax.set_ylim(-38,28)
ax.set_xlim(-23,60)
# Out:
# /home/ck/miniconda3/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /home/ck/miniconda3/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# (-23.0, 60.0)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (y: 2080, x: 2268)
# Coordinates:
#     time     datetime64[ns] 2010-11-21T18:00:00
#     lat      (y, x) float32 -37.56 -37.56 -37.55 -37.55 ... 27.21 27.22 27.23
#     lon      (y, x) float32 -27.16 -27.12 -27.08 -27.03 ... 64.95 65.08 65.2
# Dimensions without coordinates: y, x
# Data variables:
#     t        (y, x) float64 nan nan nan nan nan nan ... nan nan nan nan nan nan

# %%
msg_f
# Out:
# <xarray.Dataset>
# Dimensions:  (y: 2752, x: 2491)
# Coordinates:
#     time     datetime64[ns] 2010-11-21T18:00:00
# Dimensions without coordinates: y, x
# Data variables:
#     lat      (y, x) float32 nan nan nan nan nan nan ... nan nan nan nan nan nan
#     lon      (y, x) float32 nan nan nan nan nan nan ... nan nan nan nan nan nan
# Attributes:
#     platform_long_name:  MSG2
#     instrument_name:     SEVIRI

# %%
f=plt.figure(figsize=(15,7))  # this opens a plot window
ax = f.add_subplot(111, projection=ccrs.PlateCarree())  # this opens a new plot axis
#draw_map(ax, ds['t'], ds.lon, ds.lat, levels=np.arange(-100,50), cmap='jet')
draw_map(ax, ds['t'], ds.lon, ds.lat, cmap='jet')
ax.set_ylim(-38,28)
ax.set_xlim(-23,52)
# Out:
# (-23.0, 52.0)

# %%
ds['t'].max
# Out:
# <xarray.DataArray 't' ()>
# array(-92.)
# Coordinates:
#     time     datetime64[ns] 2010-11-04T19:00:00

# %%
# %%time
# data_resolution = 5 # in km
# # make salem grid
# grid5k = u_grid.make(np.arange(lls[0],lls[1]), np.arange(lls[2],lls[3]), data_resolution*1000)
# lonN, latN = grid5k.ll_coordinates
# dlon = ds.lon.squeeze().values.T
# dlat = ds.lat.squeeze().values.T

# inds, weights, shape = u_int.interpolation_weights(dlon[np.isfinite(dlon)], dlat[np.isfinite(dlat)], lonN, latN, irregular_1d=True)
# Out:
# /home/ck/pythonWorkspace/proj_CEH/utils/u_grid.py:29: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(salem.wgs84, proj, grid_lons, grid_lats)
# CPU times: user 1min 22s, sys: 24.6 s, total: 1min 47s
# Wall time: 1min 17s

# %%
data_test = ds['t'].squeeze().values.T
try:
    data5k = u_int.interpolate_data(data_test, inds, weights, shape)
except IndexError:
    print('Interpolation problem, continue')

# %%
data_test.shape
# Out:
# (2268, 2080)

# %%
lonN[:,0]
# Out:
# array([-25., -25., -25., ..., -25., -25., -25.])

# %%
lonN[0,1::] - lonN[0,0:-1]
# Out:
# array([0.04491576, 0.04491576, 0.04491576, ..., 0.04491576, 0.04491576,
#        0.04491576])

# %%
f=plt.figure(figsize=(15,7))  # this opens a plot window
ax = f.add_subplot(111, projection=ccrs.PlateCarree())  # this opens a new plot axis
#draw_map(ax, ds['t'], ds.lon, ds.lat, levels=np.arange(-100,50), cmap='jet')
draw_map(ax, data5k, lonN, latN,levels=np.arange(-70,-50,1), cmap='jet')
ax.set_ylim(-38,28)
ax.set_xlim(-23,52)
# Out:
# /home/ck/miniconda3/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /home/ck/miniconda3/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# (-23.0, 52.0)

# %%
lonN.shape
# Out:
# (1482, 1758)

# %%
# %%time
# data_resolution = 5 # in km
# # make salem grid
# grid5k = u_grid.make(np.arange(lls[0],lls[1]), np.arange(lls[2],lls[3]), data_resolution*1000)
# dlon = ds.lon.squeeze().values.T
# dlat = ds.lat.squeeze().values.T
# inds, weights, shape = u_int.interpolation_weights_grid(dlon, dlat, grid5k)

# %%
# data_resolution = 3 # in km
# # make salem grid
# grid3k = u_grid.make(np.arange(lls[0],lls[1]), np.arange(lls[2],lls[3]), data_resolution*1000)
# dlon = ds.lon.squeeze().values.T
# dlat = ds.lat.squeeze().values.T
# inds3, weights3, shape3 = u_int.interpolation_weights_grid(dlon, dlat, grid3k)

# %%
# regrid5k = grid5k.to_dataset()

# %%
# %%time
wObjn = cores.dataset('METEOSAT5K_vera')
wObjn.read_img(data5k, lonN, latN, edge_smoothing=True)
wObjn.applyWavelet(normed='scale')
nowcast = wObjn.scaleWeighting(wtype='nflics')
# Out:
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -91.29082356919376 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# CPU times: user 10.7 s, sys: 324 ms, total: 11 s
# Wall time: 11 s

# %%
# %%time
# wObjn = cores.dataset('METEOSAT5K_veraLS')
# wObjn.read_img(data5k, lonN, latN, edge_smoothing=True)
# wObjn.applyWavelet(normed='scale')
# nowcast3kweight = wObjn.scaleWeighting(wtype='nflics3k')

# %%
ds['t'].values
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [21., 21., 21., ..., nan, nan, nan],
#        [21., 21., 21., ..., nan, nan, nan],
#        [21., 21., 21., ..., nan, nan, nan]])

# %%
# %%time
wObj = cores.dataset('METEOSAT3K_veraLS')
wObj.read_img(ds['t'].values, ds.lon.values, ds.lat.values, edge_smoothing=False)
wObj.applyWavelet(normed='scale')
#current_nflics = wObj.scaleWeighting(wtype='nflics3k')
new_nflics = wObj.scaleWeighting(wtype='nflics3k')
# Out:
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -92.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# CPU times: user 28.8 s, sys: 2.24 s, total: 31.1 s
# Wall time: 31.1 s

# %%
# %%time
# wObj = cores.dataset('METEOSAT3K_veraLS')
# wObj.read_img(ds['t'].values, ds.lon.values, ds.lat.values, edge_smoothing=False)
# wObj.applyWavelet(normed='scale')
# current_nflics_std = wObj.scaleWeighting(wtype='nflicsv2')
# #new_nflics_std = wObj.scaleWeighting(wtype='nflics')

# %%
box = [0,20,-5,10]
tmax = -65
tmin = -85
#perc = np.percentile(current_nflics[current_nflics>0],90)
f = plt.figure(figsize=(12,5), dpi=200)
ax = f.add_subplot(121, projection=ccrs.PlateCarree())
draw_map(ax, wObj.original, ds.lon, ds.lat, cmap='jet', levels=np.arange(tmin,tmax,2))
ax.contour(lonN, latN,  nowcast, levels=[-1,1,100], cmap='jet', linewidths=0.6)
ax.set_ylim(box[2], box[3])
ax.set_xlim(box[0],box[1])
ax.set_title('5km nowcast NFLICS')

ax = f.add_subplot(122, projection=ccrs.PlateCarree())
#perc = np.percentile(current_nflics_std[current_nflics_std>0],90)
draw_map(ax, wObj.original, ds.lon, ds.lat, cmap='jet', levels=np.arange(tmin,tmax,2))
ax.contour(ds.lon, ds.lat,  new_nflics, levels=[-1,1,200], cmap='jet', linewidths=0.6)
ax.set_ylim(box[2], box[3])
ax.set_xlim(box[0],box[1])
ax.set_title('Current, stddev normalisation')
# Out:
# Text(0.5, 1.0, 'Current, stddev normalisation')

# %%
# box = [-15,0,2,11]
# tmax = -65
# tmin = -85
# #perc = np.percentile(current_nflics[current_nflics>0],90)
# f = plt.figure(figsize=(12,8), dpi=200)
# ax = f.add_subplot(221, projection=ccrs.PlateCarree())
# draw_map(ax, wObj.original, ds.lon, ds.lat, cmap='jet', levels=np.arange(tmin,tmax,2))
# ax.contour(lonN, latN,  nowcast, levels=[-1,1,100], cmap='jet', linewidths=0.6)
# ax.set_ylim(box[2], box[3])
# ax.set_xlim(box[0],box[1])
# ax.set_title('Current, scale normalisation')

# ax = f.add_subplot(222, projection=ccrs.PlateCarree())
# #perc = np.percentile(new_nflics[new_nflics>0],90)
# draw_map(ax, wObj.original, ds.lon, ds.lat, cmap='jet', levels=np.arange(tmin,tmax,2))
# ax.contour(lonN, latN,  nowcast3kweight, levels=[-1,1,100], cmap='jet', linewidths=0.6)
# ax.set_ylim(box[2], box[3])
# ax.set_xlim(box[0],box[1])
# ax.set_title('New, scale normalisation')

# ax = f.add_subplot(223, projection=ccrs.PlateCarree())
# #perc = np.percentile(current_nflics_std[current_nflics_std>0],90)
# draw_map(ax, wObj.original, ds.lon, ds.lat, cmap='jet', levels=np.arange(tmin,tmax,2))
# ax.contour(ds.lon, ds.lat,  new_nflics, levels=[-1,1,200], cmap='jet', linewidths=0.6)
# ax.set_ylim(box[2], box[3])
# ax.set_xlim(box[0],box[1])
# ax.set_title('Current, stddev normalisation')

# ax = f.add_subplot(224, projection=ccrs.PlateCarree())
# #perc = np.percentile(new_nflics_std[new_nflics_std>0],90)
# draw_map(ax, wObj.original, ds.lon, ds.lat, cmap='jet', levels=np.arange(tmin,tmax,2))
# ax.contour(ds.lon, ds.lat,  current_nflics_std, levels=[-1,1,150], cmap='jet', linewidths=0.6)
# ax.set_ylim(box[2], box[3])
# ax.set_xlim(box[0],box[1])
# ax.set_title('New, stddev normalisation')
# Out:
# Text(0.5, 1.0, 'New, stddev normalisation')

# %%
prcp = xr.open_dataset(glob.glob('/media/ck/LStorage/global_water/other/nflics/GPM/2010/11/3B-HHR.MS.MRG.3IMERG.20101121*.1110.V06B*')[0])  #, group='/Grid/'
prcp = prcp['precipitationCal'].squeeze()
#prcp = prcp['IRprecipitation'].squeeze()
# pbox = prcp.sel(lat=slice(np.min(latitudes), np.max(latitudes)), lon=slice(np.min(longitudes),np.max(longitudes)))
#prcp = prcp.sel(lon=slice(-19,0), lat=slice(8,18.5))

# %%
f=plt.figure(figsize=(15,5), dpi=200)  # this opens a plot window
ax = f.add_subplot(121, projection=ccrs.PlateCarree())  # this opens a new plot axis
#draw_map(ax, ds['t'], ds.lon, ds.lat, levels=np.arange(-100,50), cmap='jet')
tmin = -90
tmax = 50
draw_map(ax, wObj.original, ds.lon, ds.lat, cmap='jet', levels=np.arange(tmin,tmax,2))
ax.contour(lonN, latN,  nowcast, levels=[-1,0,150], cmap='Reds', linewidths=2)
ax.set_ylim(box[2], box[3])
ax.set_xlim(box[0],box[1])
ax.set_title('')
# ax.set_ylim(-38,28)
# ax.set_xlim(-23,52)

#box = [18,32,-20,-10]
ax = f.add_subplot(122, projection=ccrs.PlateCarree())  # this opens a new plot axis
#draw_map(ax, ds['t'], ds.lon, ds.lat, levels=np.arange(-100,50), cmap='jet')
tmin = -90
tmax = -40
draw_map(ax, wObj.original, ds.lon, ds.lat, cmap='jet', levels=np.arange(tmin,tmax,2))
ax.contour(lonN, latN,   nowcast, levels=[-1,0,150], cmap='jet_r', linewidths=0.6)
ax.set_ylim(box[2], box[3])
ax.set_xlim(box[0],box[1])
ax.set_title('')
# ax.set_ylim(-38,28)
# ax.set_xlim(-23,52)
plt.tight_layout()
#f.savefig("/home/ck/DIR/cornkle/data/nflics/core_tests/map_SAfr.jpg")

# %%
f=plt.figure(figsize=(15,5), dpi=200)  # this opens a plot window
ax = f.add_subplot(121, projection=ccrs.PlateCarree())  # this opens a new plot axis
#draw_map(ax, ds['t'], ds.lon, ds.lat, levels=np.arange(-100,50), cmap='jet')
tmin = -90
tmax = 50
draw_map(ax, wObj.original, ds.lon, ds.lat, cmap='jet', levels=np.arange(tmin,tmax,2))
ax.contour(ds.lon, ds.lat,  current_nflics_std, levels=[-1,0,150], cmap='Reds', linewidths=2)
ax.set_ylim(box[2], box[3])
ax.set_xlim(box[0],box[1])
ax.set_title('')
# ax.set_ylim(-38,28)
# ax.set_xlim(-23,52)

#box = [18,32,-20,-10]
ax = f.add_subplot(122, projection=ccrs.PlateCarree())  # this opens a new plot axis
#draw_map(ax, ds['t'], ds.lon, ds.lat, levels=np.arange(-100,50), cmap='jet')
tmin = -90
tmax = -40
draw_map(ax, wObj.original, ds.lon, ds.lat, cmap='jet', levels=np.arange(tmin,tmax,2))
ax.contour(ds.lon, ds.lat,  current_nflics_std, levels=[-1,0,150], cmap='jet_r', linewidths=0.6)
ax.set_ylim(box[2], box[3])
ax.set_xlim(box[0],box[1])
ax.set_title('')
# ax.set_ylim(-38,28)
# ax.set_xlim(-23,52)
plt.tight_layout()
#f.savefig("/home/ck/DIR/cornkle/data/nflics/core_tests/map_SAfr.jpg")
# Out:
# /home/ck/miniconda3/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /home/ck/miniconda3/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '

# %%
tmax = -40
tmin = -85
prcp = prcp.sel(lon=slice(box[0],box[1]), lat=slice(box[2],box[3]))
perc = np.percentile(current_nflics[current_nflics>0],90)
f = plt.figure(figsize=(12,8), dpi=200)
ax = f.add_subplot(221, projection=ccrs.PlateCarree())
draw_map(ax,prcp.T, prcp.lon, prcp.lat, cmap='jet', levels=[2,10,20,30])
ax.contour(lonN, latN,  nowcast, levels=[-1,0,perc], cmap='jet_r', linewidths=0.6)
ax.set_ylim(box[2], box[3])
ax.set_xlim(box[0],box[1])
ax.set_title('Current, scale normalisation')

ax = f.add_subplot(222, projection=ccrs.PlateCarree())
perc = np.percentile(new_nflics[new_nflics>0],90)
draw_map(ax,prcp.T, prcp.lon, prcp.lat, cmap='jet', levels=[2,10,20,30])
ax.contour(ds.lon, ds.lat,  new_nflics, levels=[-1,0,perc], cmap='jet_r', linewidths=0.6)
ax.set_ylim(box[2], box[3])
ax.set_xlim(box[0],box[1])
ax.set_title('New, scale normalisation')

ax = f.add_subplot(223, projection=ccrs.PlateCarree())
perc = np.percentile(current_nflics_std[current_nflics_std>0],90)
draw_map(ax,prcp.T, prcp.lon, prcp.lat, cmap='jet', levels=[2,10,20,30])
ax.contour(ds.lon, ds.lat,  current_nflics_std, levels=[-1,0,perc], cmap='jet_r', linewidths=0.6)
ax.set_ylim(box[2], box[3])
ax.set_xlim(box[0],box[1])
ax.set_title('Current, stddev normalisation')

ax = f.add_subplot(224, projection=ccrs.PlateCarree())
perc = np.percentile(new_nflics_std[new_nflics_std>0],90)
draw_map(ax,prcp.T, prcp.lon, prcp.lat, cmap='jet', levels=[2,10,20,30])
ax.contour(ds.lon, ds.lat,  new_nflics_std, levels=[-1,0,perc], cmap='jet_r', linewidths=0.6)
ax.set_ylim(box[2], box[3])
ax.set_xlim(box[0],box[1])
ax.set_title('New, stddev normalisation')
# Out:
# Text(0.5, 1.0, 'New, stddev normalisation')

# %%
#lls = [5,35,-20,10]

lls = [10, 35, -35, -10]

k3LS = {'rain':[], 'wav' : [], 't' : []}
k3LS_grid = {'rain':[], 'wav' : [], 't' : []}
k3LS_nflics = {'rain':[], 'wav' : [], 't' : []}
k3LS_bigD = {'rain':[], 'wav' : [], 't' : []}
k3 = {'rain':[], 'wav' : [], 't' : []}
nflics = {'rain':[], 'wav' : [], 't' : []}
nflicsLS = {'rain':[], 'wav' : [], 't' : []}
alls3k = []
alls3k_reg = []
alls5k = []

msg_obj = msg_panAfrica.ReadMsg(cnst.other_drive+'nflics/SSA_data/', y1=2010, y2=2010, months=[11])

msg_obj.set_date(2010,11,2,15,0)
ds = msg_obj.get_data()
ds = ds.where((ds.lon >= lls[0]) & (ds.lon <= lls[1]) & (ds.lat >= lls[2]) & (ds.lat <= lls[3]), drop=True)
dlon = ds.lon.squeeze().values.T
dlat = ds.lat.squeeze().values.T
data = ds['t'].squeeze().values.T

prcp = xr.open_dataset(glob.glob(cnst.other_drive+'nflics/GPM/2010/11/3B-HHR.MS.MRG.3IMERG.20101115*.0000.V06B*')[0])
prcp = prcp['precipitationCal'].squeeze()
prcp = prcp.sel(lon=slice(lls[0]-0.5,lls[1]+0.5), lat=slice(lls[2]-0.5,lls[3]+0.5))
print(prcp.values.shape)

data_resolution = 3 # in km
# make salem grid
grid3k = u_grid.make(np.arange(lls[0],lls[1]), np.arange(lls[2],lls[3]), data_resolution*1000)
inds3, weights3, shape3 = u_int.interpolation_weights_grid(dlon, dlat, grid3k)
data_resolution = 5 # in km
# make salem grid
grid5k = u_grid.make(np.arange(lls[0],lls[1]), np.arange(lls[2],lls[3]), data_resolution*1000)
inds5, weights5, shape5 = u_int.interpolation_weights_grid(dlon, dlat, grid5k)


#data3k = u_int.interpolate_data(data, inds3, weights3, shape3)
lon3k, lat3k = grid3k.ll_coordinates

#data5k = u_int.interpolate_data(data, inds, weights, shape)
lon5k, lat5k = grid5k.ll_coordinates


lons, lats = np.meshgrid(prcp.lon.values, prcp.lat.values)
indsp3, weightsp3, shapep3 = u_int.interpolation_weights(prcp.lon, prcp.lat , lon3k, lat3k)

indsp5, weightsp5, shapep5 = u_int.interpolation_weights(prcp.lon, prcp.lat , lon5k, lat5k)

inds_msg, weights_msg, shape_msg = u_int.interpolation_weights(prcp.lon, prcp.lat , dlon, dlat)


for dd in range(1,31):
    for hh in range(15,22):
       # for mins in [0,30]:
        
        print('Doing ', 2010, 11, dd, hh)
       
        msg_obj.set_date(2010,11,dd,hh,0)
        ds = msg_obj.get_data()
        ds = ds.where((ds.lon >= lls[0]) & (ds.lon <= lls[1]) & (ds.lat >= lls[2]) & (ds.lat <= lls[3]), drop=True)
        dlon = ds.lon.squeeze().values.T
        dlat = ds.lat.squeeze().values.T
        data = ds['t'].squeeze().values.T
        
        t3k = u_int.interpolate_data(data, inds3, weights3, shape3)
        t5k = u_int.interpolate_data(data, inds5, weights5, shape5)
        
        wObj = cores.dataset('METEOSAT3K_veraLS')
        wObj.read_img(data, dlon, dlat, edge_smoothing=False)
        wObj.applyWavelet(normed='scale')
        k3small = wObj.scaleWeighting(wtype='nflics3k')
        k3coarse = wObj.scaleWeighting(wtype='nflics')
        k3bigDomain = wObj.scaleWeighting(wtype='nflicsv2')
        
        wObj = cores.dataset('METEOSAT3K_veraLS')
        wObj.read_img(t3k, lon3k, lat3k, edge_smoothing=False)
        wObj.applyWavelet(normed='scale')
        k3small_regrid = wObj.scaleWeighting(wtype='nflics3k')
        
        wObj = cores.dataset('METEOSAT3K_test')
        wObj.read_img(data, dlon, dlat, edge_smoothing=False)
        wObj.applyWavelet(normed='scale')
        k3_fine = wObj.scaleWeighting(wtype='nflics3k')
        
       # ipdb.set_trace()
        wObj = cores.dataset('METEOSAT5K_vera')
        wObj.read_img(t5k, lon5k, lat5k, edge_smoothing=True)
        wObj.applyWavelet(normed='scale')
        k5_nflics = wObj.scaleWeighting(wtype='nflics')
        
        wObj = cores.dataset('METEOSAT5K_veraLS')
        wObj.read_img(t5k, lon5k, lat5k, edge_smoothing=False)
        wObj.applyWavelet(normed='scale')
        k5_nflicsLS = wObj.scaleWeighting(wtype='nflics')


        gpm_hour = hh*60-30
        #ipdb.set_trace()
        prcp = xr.open_dataset(glob.glob(cnst.other_drive+'nflics/GPM/2010/11/3B-HHR.MS.MRG.3IMERG.201011'+str(dd).zfill(2)+'*.'+str(gpm_hour).zfill(4)+'.V06B*')[0])  #, group='/Grid/'
        
        prcp = prcp['precipitationCal'].squeeze()
        prcp = prcp.sel(lon=slice(lls[0]-0.5,lls[1]+0.5), lat=slice(lls[2]-0.5,lls[3]+0.5))
        print(prcp.values.shape)
        try:
            prcp_5k = u_int.interpolate_data(prcp.T.values, indsp5, weightsp5, shapep5)
            prcp_3k = u_int.interpolate_data(prcp.T.values, indsp3, weightsp3, shapep3)
            prcp_msg = u_int.interpolate_data(prcp.T.values, inds_msg, weights_msg, shape_msg)
            #ipdb.set_trace()
        except IndexError:
            ipdb.set_trace()
            print('Interpolation problem, continue')
        
        thresh = 1
        try:
            ispos_3k = np.where((k3small != 0) & (prcp_msg >=thresh)) # large-scale 3k, with new nflics weighting
            ispos_3knf = np.where((k3coarse != 0) & (prcp_msg >=thresh)) #large-scale 3k, with current nflics weithing
            ispos_3bigd = np.where((k3bigDomain != 0) & (prcp_msg >=thresh)) #large-scale 3k, with complex big domain weighting "small scales" variable.
            ispos_3knfine = np.where((k3_fine != 0) & (prcp_msg >=thresh)) # fine-scale 3k with more scales, with new nflics weighting (most different)
            ispos_3msg = np.where((k3small_regrid != 0) & (prcp_3k >=thresh)) # large-scale 3k, with new nflics weithing regridded to regular 3km 
            ispos_5k = np.where((k5_nflics != 0) & (prcp_5k >=thresh)) # current nflics (5k, only 3 scales, nflics weighting)
            ispos_5kLS = np.where((k5_nflicsLS != 0) & (prcp_5k >=thresh)) # potential new 5k, 5 scales, nflics weithing  [none uses smoothing here!!]
        except:
            continue
            
        k3LS['rain'].extend(prcp_msg[ispos_3k].flat)
        k3LS_grid['rain'].extend(prcp_msg[ispos_3knf].flat)
        k3LS_bigD['rain'].extend(prcp_msg[ispos_3bigd].flat)
        k3['rain'].extend(prcp_msg[ispos_3knfine].flat)
        k3LS_nflics['rain'].extend(prcp_3k[ispos_3msg].flat)
        nflics['rain'].extend(prcp_5k[ispos_5k].flat)
        nflicsLS['rain'].extend(prcp_5k[ispos_5kLS].flat)
        
        k3LS['wav'].extend(k3small[ispos_3k].flat)
        k3LS_grid['wav'].extend(k3coarse[ispos_3knf].flat)
        k3LS_bigD['wav'].extend(k3bigDomain[ispos_3bigd].flat)
        k3['wav'].extend(k3_fine[ispos_3knfine].flat)
        k3LS_nflics['wav'].extend(k3small_regrid[ispos_3msg].flat)
        nflics['wav'].extend(k5_nflics[ispos_5k].flat)
        nflicsLS['wav'].extend(k5_nflicsLS[ispos_5kLS].flat)
        
        k3LS['t'].extend(data[ispos_3k].flat)
        k3LS_grid['t'].extend(data[ispos_3knf].flat)
        k3LS_bigD['t'].extend(data[ispos_3bigd].flat)
        k3['t'].extend(data[ispos_3knfine].flat)
        k3LS_nflics['t'].extend(t3k[ispos_3msg].flat)
        nflics['t'].extend(t5k[ispos_5k].flat)
        nflicsLS['t'].extend(t5k[ispos_5kLS].flat)
        
        
        alls3k.extend(prcp_msg[prcp_msg>=thresh].flat)
        alls3k_reg.extend(prcp_3k[prcp_3k>=thresh].flat)
        alls5k.extend(prcp_5k[prcp_5k>=thresh].flat)
# Out:
# (260, 197)
# /home/ck/pythonWorkspace/proj_CEH/utils/u_grid.py:29: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(salem.wgs84, proj, grid_lons, grid_lats)
# /home/ck/pythonWorkspace/proj_CEH/utils/u_grid.py:29: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(salem.wgs84, proj, grid_lons, grid_lats)
# Doing  2010 11 1 15
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -85.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -84.43878395972871 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -85.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -84.72505184333242 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -84.72505184333242 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 1 16
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -84.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -82.63845528477485 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -84.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -81.28575064566114 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -81.28575064566114 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 1 17
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -86.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -85.65017671836824 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -86.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -82.30065396522656 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -82.30065396522656 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 1 18
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -80.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -79.99674252350026 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -80.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -79.51761295349009 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -79.51761295349009 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 1 19
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -77.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -76.20950628016408 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -77.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -76.87684566029267 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -76.87684566029267 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 1 20
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -73.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -72.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -73.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -72.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -72.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 1 21
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -75.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -72.86037847575462 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -75.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -72.0981750418691 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -72.0981750418691 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 2 15
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -88.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -81.77974270790179 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -88.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -81.28809695784236 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -81.28809695784236 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 2 16
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -85.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -83.285924659173 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -85.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -83.47291620562682 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -83.47291620562682 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 2 17
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -85.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -83.96030785319094 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -85.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -83.9121165697769 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -83.9121165697769 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 2 18
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -87.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -82.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -87.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -81.96111040501279 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -81.96111040501279 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 2 19
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -87.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -81.8054515811207 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -87.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -81.31401535000124 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -81.31401535000124 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 2 20
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -87.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -85.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -87.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -84.42481515106238 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -84.42481515106238 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 2 21
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -90.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -74.8207327154517 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -90.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -74.62572675065631 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -74.62572675065631 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 3 15
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -84.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -77.46855015601597 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -84.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -77.26464755012037 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -77.26464755012037 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 3 16
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -87.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -76.61198639251458 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -87.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -76.3264850407843 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -76.3264850407843 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 3 17
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -89.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -88.44787742206947 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -89.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -87.377935851475 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -87.377935851475 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 3 18
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -81.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -79.70101490805554 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -81.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -79.70101490805557 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -79.70101490805557 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 3 19
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -74.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -73.9199499885126 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -74.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -73.91994998851261 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -73.91994998851261 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 3 20
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -70.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -69.53868688116744 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -70.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -68.87499187095692 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -68.87499187095692 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 3 21
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -66.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -65.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -66.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -65.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -65.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 4 15
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -87.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -83.39074507926641 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -87.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -82.3730465882015 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -82.3730465882015 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 4 16
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -88.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -85.42492482439401 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -88.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -85.96170171502727 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -85.96170171502727 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 4 17
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -83.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -79.17282464374034 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -83.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -79.95466398633441 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -79.95466398633441 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 4 18
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -81.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -79.49110903008514 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -81.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -80.59155102935105 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -80.59155102935105 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 4 19
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -81.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -80.19787550429348 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -81.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -80.13920493325489 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -80.13920493325489 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 4 20
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -79.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -78.7968752407454 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -79.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -78.27743873498943 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -78.27743873498943 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 4 21
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -78.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -77.87936417886186 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -78.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -77.68069536490408 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -77.68069536490408 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 5 15
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -90.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -88.93037375197788 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -90.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -87.99164473409363 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -87.99164473409363 0.0
# ...
#   96.         145.50879038]
# outmin -90.65495353061839 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -91.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -90.08420982174862 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -90.08420982174862 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 29 20
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -91.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -90.55728820093451 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -91.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -89.50151467961416 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -89.50151467961416 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 29 21
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -89.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -87.65764278218238 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -89.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -87.19945349701965 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -87.19945349701965 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 30 15
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -85.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -84.69264294742638 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -85.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -83.99604093311146 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -83.99604093311146 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 30 16
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -83.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -82.13766224539427 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -83.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -82.71390600294966 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -82.71390600294966 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 30 17
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -83.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -82.54868313628936 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -83.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -82.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -82.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 30 18
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -83.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -81.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -83.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -80.60413788217787 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -80.60413788217787 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 30 19
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -79.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -77.76055038019207 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -79.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -77.07567871373429 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -77.07567871373429 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 30 20
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -79.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -78.57736063206717 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -79.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -77.6930948114383 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -77.6930948114383 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)
# Doing  2010 11 30 21
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# Please provide regular grid coordinates.
# outmin -88.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 12.          18.1885988   27.56876052  41.78642704  63.33637972
#   96.         145.50879038]
# outmin -81.95743032995067 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 86.20994625645575
# Initialised wavelet with scales:  [  9.          12.552693    17.50778905  24.41887789  34.05807528
#   47.50228479  66.25351084  92.40666462 128.88361021 179.75959904]
# Please provide regular grid coordinates.
# outmin -88.0 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# power threshold 177.2736920368411
# Initialised wavelet with scales:  [25.         35.35533906 50.        ]
# outmin -81.92767818309324 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# Initialised wavelet with scales:  [ 25.          35.35533906  50.          70.71067812 100.        ]
# outmin -81.92767818309324 0.0
# Wavelet coefficients and power normed by: scale Possible tags: "scale", "stddev"
# Assuming Meteosat MSG dataset. If incorrect, please set explicit data_tag keyword for .scaleWeighting
# (260, 197)

# %%
# import pickle as pkl
# strt = {}
# for dat in ['3km LS, 3k weighting', '3km LS, nflics weighting',  '3km small, 3kweighting', '3km LS, 3k regridded, 3k weighting', '5k, nflics', '5k LS definition, nflics weighting','3k native rain', '3k regrid rain', '5k rain']:
#     strt[dat]=pkl.load(open("/home/ck/DIR/cornkle/data/nflics/core_tests/"+dat+".p", "rb"))

# keys = strt.keys()

# %%
# keys
# Out:
# dict_keys(['3km LS, 3k weighting', '3km LS, nflics weighting', '3km small, 3kweighting', '3km LS, 3k regridded, 3k weighting', '5k, nflics', '5k LS definition, nflics weighting', '3k native rain', '3k regrid rain', '5k rain'])

# %%
def calc_treshReached(dat, thresh):
    return np.sum(np.array(dat)>thresh)/np.sum(np.isfinite(dat))

# %%
def calc_treshReached_vsObs(dat, obs, thresh):
    return np.sum(np.array(dat)>thresh)/np.sum(np.isfinite(dat)) / np.sum(np.array(obs)>thresh)/np.sum(np.isfinite(obs))

# %%
def calc_treshMissed(dat, obs, thresh):
    return np.sum(np.array(dat)>thresh)/np.sum(np.array(obs)>thresh)

# %%
def percentile(dat, wav, thresh, perc):
    pval = np.percentile(wav, perc)
    dats = np.array(dat)[np.array(wav)>=pval]
    return np.sum(dats>thresh)/np.sum(np.isfinite(dats))

# %%
def calc_treshMissed(dat, obs, thresh):
    return np.sum(np.array(dat)>thresh)/np.sum(np.array(obs)>thresh)

# %%
treached = []
tnames = []
for dat in [(k3LS['rain'], '3km LS, 3k weighting'), (k3LS_grid['rain'], '3km LS, nflics weighting'), (k3LS_bigD['rain'], '3km LS, bigDomain weighting nfv2'), (k3['rain'], '3km small, 3kweighting'), (k3LS_nflics['rain'], '3km LS, 3k regridded, 3k weighting'), (nflics['rain'], '5k, nflics'), (nflicsLS['rain'], '5k LS definition, nflics weighting'), (alls3k, '3k native rain'), (alls3k_reg, '3k regrid rain'), (alls5k, '5k rain')]:
    cc = calc_treshReached(dat[0],20)
    print(cc, dat[1])
    treached.append(cc)
    tnames.append(dat[1])
# Out:
# 0.014928525107319799 3km LS, 3k weighting
# 0.011727434984764376 3km LS, nflics weighting
# 0.01478049987626825 3km LS, bigDomain weighting nfv2
# 0.013430530330018162 3km small, 3kweighting
# 0.012736360790138557 3km LS, 3k regridded, 3k weighting
# 0.008165688739871472 5k, nflics
# 0.009370938393553418 5k LS definition, nflics weighting
# 0.003458217018858159 3k native rain
# 0.0037427286383862686 3k regrid rain
# 0.0037623221709268276 5k rain

# %%
# import pickle as pkl
# for dat in [(k3LS, '3km LS, 3k weighting'), (k3LS_grid, '3km LS, nflics weighting'), (k3, '3km small, 3kweighting'), (k3LS_nflics, '3km LS, 3k regridded, 3k weighting'), (nflics, '5k, nflics'), (nflicsLS, '5k LS definition, nflics weighting'), (alls3k, '3k native rain'), (alls3k_reg, '3k regrid rain'), (alls5k, '5k rain')]:
#     pkl.dump(dat[0], open("/home/ck/DIR/cornkle/data/nflics/core_tests/"+dat[1]+"_southAfrica0-35S.p", "wb"))

# %%
# #save percentiles for filter or contour use
# for dat in [(k3LS, '3km LS, 3k weighting'), (k3LS_grid, '3km LS, nflics weighting'), (k3, '3km small, 3kweighting'), (k3LS_nflics, '3km LS, 3k regridded, 3k weighting'), (nflics, '5k, nflics'), (nflicsLS, '5k LS definition, nflics weighting')]:
#     perc = np.percentile(dat[0]['wav'], np.arange(50,100,5))
#     print(perc)
#     pkl.dump(perc, open("/home/ck/DIR/cornkle/data/nflics/core_tests/"+dat[1]+"_50-95_5step_percentiles.p", "wb"))
# Out:
# [145.68925912 154.6045336  164.40441867 175.49540259 188.14664331
#  202.78138813 219.82352822 241.0763581  270.31755423 316.79180866]
# [102.74613829 111.73680907 121.8930548  133.27193065 146.28414377
#  161.59669112 180.14323807 203.33182855 233.80664645 283.38017364]
# [281.94459958 297.05066143 313.73431319 332.4328058  353.72631993
#  378.22639069 407.24986078 443.01907842 490.6509716  567.7480026 ]
# [142.26155914 150.72534661 160.10214619 170.65636706 182.75239252
#  196.54562398 212.96568346 233.51007126 262.24086651 308.59514012]
# [ 39.83819145  44.06957418  48.95269823  54.68772905  61.54554385
#   69.90648702  80.55575274  94.77742261 115.38045487 151.78379602]
# [ 81.36445366  89.23964238  98.27792328 108.54026771 120.40546614
#  134.19061669 150.97449914 173.15149292 204.38659597 255.72803878]

# %%
tcaught = []
for dat in [(k3LS['rain'], '3km LS, 3k weighting', alls3k), (k3LS_grid['rain'], '3km LS, nflics weighting', alls3k), (k3LS_bigD['rain'], '3km LS, bigDomain weighting nfv2', alls3k), (k3['rain'], '3km small, 3kweighting', alls3k), (k3LS_nflics['rain'], '3km LS, 3k regridded, 3k weighting', alls3k_reg), (nflics['rain'], '5k, nflics', alls5k), (nflicsLS['rain'], '5k LS definition, nflics weighting', alls5k)]:

    cc = calc_treshMissed(dat[0],dat[2], 30)
    print(cc, dat[1], len(dat[0]))
    tcaught.append(cc)
# Out:
# 0.4485278763833786 3km LS, 3k weighting 535083
# 0.7824180413447483 3km LS, nflics weighting 976002
# 0.41929421591146376 3km LS, bigDomain weighting nfv2 505125
# 0.5926080601378159 3km small, 3kweighting 684932
# 0.2449478697387051 3km LS, 3k regridded, 3k weighting 549372
# 0.22632711621233859 5k, nflics 286320
# 0.415351506456241 5k LS definition, nflics weighting 384700

# %%
tfrac = []
for dat in [(k3LS['rain'], '3km LS, 3k weighting', alls3k), (k3LS_grid['rain'], '3km LS, nflics weighting', alls3k), (k3LS_bigD['rain'], '3km LS, bigDomain weighting nfv2', alls3k), (k3['rain'], '3km small, 3kweighting', alls3k), (k3LS_nflics['rain'], '3km LS, 3k regridded, 3k weighting', alls3k_reg), (nflics['rain'], '5k, nflics', alls5k), (nflicsLS['rain'], '5k LS definition, nflics weighting', alls5k)]:

    cc = calc_treshReached_vsObs(dat[0],dat[2], 25)
    print(cc, dat[1])
    tfrac.append(cc)
# Out:
# 1.8357060174982255e-13 3km LS, 3k weighting
# 1.5980536640123232e-13 3km LS, nflics weighting
# 1.8257202301371226e-13 3km LS, bigDomain weighting nfv2
# 1.769665763868692e-13 3km small, 3kweighting
# 8.718169481432022e-14 3km LS, 3k regridded, 3k weighting
# 4.34516169002918e-13 5k, nflics
# 5.442244560415187e-13 5k LS definition, nflics weighting

# %%
for tr, tc, tn in zip(treached,tcaught,tnames):
    print(tr*tc, tn)
# Out:
# 0.006695859663922098 3km LS, 3k weighting
# 0.009175756710777222 3km LS, nflics weighting
# 0.006197378106399383 3km LS, bigDomain weighting nfv2
# 0.007959040525494163 3km small, 3kweighting
# 0.0031197444437680104 3km LS, 3k regridded, 3k weighting
# 0.0018481167843826753 5k, nflics
# 0.003892233378671039 5k LS definition, nflics weighting

# %%
f = plt.figure(figsize=(9,6), dpi=200)
ax = f.add_subplot(111)
plotdic = []
for dat in [(k3LS, '3km LS, new weighting'), (k3LS_grid, '3km LS, nflics weighting'), (k3LS_bigD, '3km LS bigDomain v2'), (nflics, '5k nflics'), (nflicsLS, '5k LS, nflics weighting')]:
    treached = []
    for intens in range(5,50,5):
        cc = percentile(dat[0]['rain'],dat[0]['wav'], intens, 75)
        treached.append(cc)
    plotdic.append((treached,dat[1]))

for pp in plotdic:    
    ax.plot(range(5,50,5), pp[0], label=pp[1])

ax.set_title("Intensity probability for 75th centile power (%) (x[treshhold]/x)")
plt.legend()
#f.savefig("/home/ck/DIR/cornkle/data/nflics/core_tests/"+'rainP_75p_wpower.jpg')

# %%
f = plt.figure(figsize=(9,6), dpi=200)
ax = f.add_subplot(111)
plotdic = []
for dat in [(k3LS, '3km LS, new weighting'), (k3LS_grid, '3km LS, nflics weighting'), (k3LS_bigD, '3km LS bigDomain v2'),  (nflics, '5k nflics'), (nflicsLS, '5k LS, nflics weighting')]:
    treached = []
    for intens in range(5,50,5):
        cc = percentile(dat[0]['rain'],dat[0]['t'], intens, 5)
        treached.append(cc)
    plotdic.append((treached,dat[1]))

for pp in plotdic:    
    ax.plot(range(5,50,5), pp[0], label=pp[1])

ax.set_title("Intensity probability for 5th centile CTT (%) (x[treshhold]/x)")
plt.legend()
#f.savefig("/home/ck/DIR/cornkle/data/nflics/core_tests/"+'rainP_5pCTT.jpg')

# %%
f = plt.figure(figsize=(9,6), dpi=200)
ax = f.add_subplot(111)
plotdic = []
for dat in [(k3LS['rain'], '3km LS, new weighting'), (k3LS_grid['rain'], '3km LS, nflics weighting'), (k3LS_bigD['rain'], '3km LS bigDomain v2'), (k3['rain'], '3km small, new weighting'), (nflics['rain'], '5k nflics'), (nflicsLS['rain'], '5k LS, nflics weighting'), (alls3k, '3k rain'), (alls5k, '5k rain')]:
    treached = []
    for intens in range(5,50,5):
        cc = calc_treshReached(dat[0],intens)
        treached.append(cc)
    plotdic.append((treached,dat[1]))

for pp in plotdic:    
    ax.plot(range(5,50,5), pp[0], label=pp[1])

ax.set_title("Intensity probability (%) (x[treshhold]/x)")
plt.legend()
 
#f.savefig("/home/ck/DIR/cornkle/data/nflics/core_tests/"+'rainP_95p_rainWav_southernAfricadomain.jpg')

# %%
f = plt.figure(figsize=(9,6), dpi=200)
ax = f.add_subplot(111)
plotdic = []
for dat in [(k3LS['rain'], '3km LS, 3k weighting', alls3k), (k3LS_grid['rain'], '3km LS, nflics weighting', alls3k), (k3LS_bigD['rain'], '3km LS bigDomain v2', alls3k), (k3['rain'], '3km small, 3kweighting', alls3k), (k3LS_nflics['rain'], '3km LS, 3k regridded, 3k weighting', alls3k_reg), (nflics['rain'], '5k, nflics', alls5k), (nflicsLS['rain'], '5k LS definition, nflics weighting', alls5k)]:
    treached = []
    for intens in range(5,50,5):
        cc = calc_treshMissed(dat[0],dat[2],intens)
        treached.append(cc)
    plotdic.append((treached,dat[1]))

for pp in plotdic:    
    ax.plot(range(5,50,5), pp[0], label=pp[1])

ax.set_title("Retained pixels per intensity (%)")
plt.legend()
 
#f.savefig("/home/ck/DIR/cornkle/data/nflics/core_tests/"+'_missedCases_southernAfricaDomain.jpg')
