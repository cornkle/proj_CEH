# %%
# common way to import is
import pandas as pd
import math
import numpy as np
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
#sns.set_palette("deep", desat=.6)
#sns.set_context(rc={"figure.figsize": (8, 4)})

# we need this to parse the uncommon timestamp
from datetime import datetime

# %%
df = pd.read_csv('/media/klein-c/Elements/sens_stud/files/lsm_2013_aug_grp/ec_wrf_merge_aug.csv' ,delimiter=',', parse_dates=['Date'])

df.set_index('Date', inplace=True, drop=True)
df.head()
df=df.loc['20130801':'20130831']
df.head()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-a26568261281> in <module>()
# ----> 1 df = pd.read_csv('/media/klein-c/Elements/sens_stud/files/lsm_2013_aug_grp/ec_wrf_merge_aug.csv' ,delimiter=',', parse_dates=['Date'])
#       2
#       3 df.set_index('Date', inplace=True, drop=True)
#       4 df.head()
#       5 df=df.loc['20130801':'20130831']
#
# ...

# %%
print 'LFX to PRCP'
print (df['WW1_LFX_NOCU_LIN_YSU_NOAH_CLIM'].mean()/ 2.5e6 *3600)/df['WW1_PRCP_NOCU_LIN_YSU_NOAH_CLIM'].mean()
print (df['WW2_LFX_NOCU_LIN_YSU_NOAH_CLIM'].mean()/ 2.5e6 *3600)/df['WW2_PRCP_NOCU_LIN_YSU_NOAH_CLIM'].mean()
print (df['WW3_LFX_NOCU_LIN_YSU_NOAH_CLIM'].mean()/ 2.5e6 *3600)/df['WW3_PRCP_NOCU_LIN_YSU_NOAH_CLIM'].mean()

print (df['EW1_LFX'].mean()/ 2.5e6 *3600)/df['EW1_PRCP'].mean()
print (df['EW2_LFX'].mean()/ 2.5e6 *3600)/df['EW2_PRCP'].mean()
print (df['EW3_LFX'].mean()/ 2.5e6 *3600)/df['EW3_PRCP'].mean()

print 'Bowen Ratio:'
print (df['WW1_HFX_NOCU_LIN_YSU_NOAH_CLIM'].mean())/df['WW1_LFX_NOCU_LIN_YSU_NOAH_CLIM'].mean()
print (df['WW2_HFX_NOCU_LIN_YSU_NOAH_CLIM'].mean())/df['WW2_LFX_NOCU_LIN_YSU_NOAH_CLIM'].mean()
print (df['WW3_HFX_NOCU_LIN_YSU_NOAH_CLIM'].mean())/df['WW3_LFX_NOCU_LIN_YSU_NOAH_CLIM'].mean()

print (df['EW1_HFX'].mean())/df['EW1_LFX'].mean()
print (df['EW2_HFX'].mean())/df['EW2_LFX'].mean()
print (df['EW3_HFX'].mean())/df['EW3_LFX'].mean()

print 'Rad_net to SW_in'
print df['EW1_rad_net'].mean()/df['EW1_SW_in'].mean()
print df['EW2_rad_net'].mean()/df['EW2_SW_in'].mean()
print df['EW3_rad_net'].mean()/df['EW3_SW_in'].mean()

print df['WW1_rad_net_NOCU_LIN_YSU_NOAH_CLIM'].mean()/df['WW1_SW_in_NOCU_LIN_YSU_NOAH_CLIM'].mean()
print df['WW2_rad_net_NOCU_LIN_YSU_NOAH_CLIM'].mean()/df['WW2_SW_in_NOCU_LIN_YSU_NOAH_CLIM'].mean()
print df['WW3_rad_net_NOCU_LIN_YSU_NOAH_CLIM'].mean()/df['WW3_SW_in_NOCU_LIN_YSU_NOAH_CLIM'].mean()

print 'Albedo'
print df['EW1_SW_out'].mean()/df['EW1_SW_in'].mean()
print df['EW2_SW_out'].mean()/df['EW2_SW_in'].mean()
print df['EW3_SW_out'].mean()/df['EW3_SW_in'].mean()

print df['WW1_SW_out_NOCU_LIN_YSU_NOAH_CLIM'].mean()/df['WW1_SW_in_NOCU_LIN_YSU_NOAH_CLIM'].mean()
print df['WW2_SW_out_NOCU_LIN_YSU_NOAH_CLIM'].mean()/df['WW2_SW_in_NOCU_LIN_YSU_NOAH_CLIM'].mean()
print df['WW3_SW_out_NOCU_LIN_YSU_NOAH_CLIM'].mean()/df['WW3_SW_in_NOCU_LIN_YSU_NOAH_CLIM'].mean()

print 'LFX Differences'

print df['WW1_rad_net_NOCU_LIN_YSU_NOAH_CLIM'][df['EW1_SW_in']>0].mean()-df['EW1_rad_net'][df['EW1_SW_in']>0].mean()
print df['WW2_rad_net_NOCU_LIN_YSU_NOAH_CLIM'][df['EW2_SW_in']>0].mean()-df['EW2_rad_net'][df['EW2_SW_in']>0].mean()
print df['WW3_rad_net_NOCU_LIN_YSU_NOAH_CLIM'][df['EW3_SW_in']>0].mean()-df['EW3_rad_net'][df['EW3_SW_in']>0].mean()


print df['EW3_rad_net'][df['EW1_SW_in']>0].mean()-df['EW1_rad_net'][df['EW1_SW_in']>0].mean()
# Out:
# LFX to PRCP
# 0.511660764187
# 0.4325866832
# 0.655811225158
# 0.479482768685
# 0.571593421593
# 1.10453811538
# Bowen Ratio:
# 0.43032434954
# 0.563538743763
# 0.546506784857
# 0.170865731931
# 0.270721553035
# 0.199389949814
# Rad_net to SW_in
# 0.590872284177
# 0.649421989855
# 0.712650063329
# 0.652356485412
# 0.74859223878
# 0.761231111702
# Albedo
# 0.216141619282
# 0.168227995089
# 0.151462841344
# 0.164839607293
# 0.15805826698
# 0.148596418587
# LFX Differences
# 96.2016690843
# 102.442686948
# 102.21155387
# 50.3833677907

# %%
# Some defaults
sns.set_style("whitegrid")
sns.set_context("poster")
plt.rcParams['figure.figsize'] = (14, 5)  # Default plot size

# %%
df['EW1_SW_in'].plot()

# %%
#var='W m-2'
dfp=df.loc['20130822':'20130831']
#fig=plt.figure()
(dfp['WW3_SW_in_NOCU_LIN_YSU_NOAH_CLIM']-dfp['WW1_SW_in_NOCU_LIN_YSU_NOAH_CLIM']).plot( style='r--', label='Short-wave in', legend=True, linewidth=2.0)
(dfp['WW3_LFX_NOCU_LIN_YSU_NOAH_CLIM']-dfp['WW1_LFX_NOCU_LIN_YSU_NOAH_CLIM']).plot(style='b', label='Latent heat flux', legend=True, linewidth=2.0)
(dfp['WW3_HFX_NOCU_LIN_YSU_NOAH_CLIM']-dfp['WW1_HFX_NOCU_LIN_YSU_NOAH_CLIM']).plot(style='g', label='Sensible heat flux', legend=True, linewidth=2.0)
plt.ylabel('W m-2')
plt.xlabel('Date')
plt.title('EC-Site Difference (Natural-Degraded) August 2013', fontsize=20)
#fig.savefig('/home/klein-c/data/WRF_LOCAL/plots_präsi/cu_all_runs/lsm_grp_2013/lfx_swin_compare.png', dpi=350)

# %%
#var='W m-2'
dfp=df.loc['20130822':'20130831']
#fig=plt.figure()
(dfp['EW3_SW_in']-dfp['EW1_SW_in']).plot( style='r--', label='Short-wave in', legend=True, linewidth=2.0)
(dfp['EW3_LFX']-dfp['EW1_LFX']).plot(style='b', label='Latent heat flux', legend=True, linewidth=2.0)
(dfp['EW3_HFX']-dfp['EW1_HFX']).plot(style='g', label='Sensible heat flux', legend=True, linewidth=2.0)
plt.ylabel('W m-2')
plt.xlabel('Date')
plt.title('EC-Site Difference (Natural-Degraded) August 2013', fontsize=20)
#print ((dfp['EW3_SW_in']-dfp['EW1_SW_in']),(dfp['EW3_LFX']-dfp['EW1_LFX'])).corr(method='pearson')
#fig.savefig('/home/klein-c/data/WRF_LOCAL/plots_präsi/cu_all_runs/lsm_grp_2013/lfx_swin_compare.png', dpi=350)

# %%
df.loc['20130601':'20130628'].filter(regex='EC').filter(regex='ALBEDO').plot()

# %%
df_diurn=df.loc['20130801':'20130831']
df_diurn.tail()
# Out:
#                       EW1_LW_in  EW1_LW_out  EW1_SW_in  EW1_SW_out  \
# Date
# 2013-08-31 19:00:00  406.633664  456.226164   2.676917    1.043417
# 2013-08-31 20:00:00  403.738217  451.706550   0.000000    0.000000
# 2013-08-31 21:00:00  410.061017  450.453267   0.000000    0.000000
# 2013-08-31 22:00:00  403.118609  447.979275   0.000000    0.000000
# 2013-08-31 23:00:00  406.150007  446.669257   0.000000    0.000000
#
#                       EW2_LW_in  EW2_LW_out  EW2_SW_in  EW2_SW_out  \
# Date
# 2013-08-31 19:00:00  399.644008  444.389675          0           0
# 2013-08-31 20:00:00  398.206860  442.117360          0           0
# 2013-08-31 21:00:00  400.328956  440.342956          0           0
# 2013-08-31 22:00:00  394.541766  438.818099          0           0
# 2013-08-31 23:00:00  391.823097  437.883764          0           0
#
#                       EW3_LW_in  EW3_LW_out  \
# Date
# 2013-08-31 19:00:00  398.485388  441.416888
# 2013-08-31 20:00:00  395.239274  437.389274
# ...

# %%
# Out:
#                       EW1_LW_in  EW1_LW_out  EW1_SW_in  EW1_SW_out  \
# Date
# 2013-08-01 00:00:00  408.377196  450.275696          0           0
# 2013-08-01 01:00:00  407.835164  447.748331          0           0
# 2013-08-01 02:00:00  412.382151  447.362485          0           0
# 2013-08-01 03:00:00  413.849470  445.342220          0           0
# 2013-08-01 04:00:00  419.000493  445.309576          0           0
#
#                       EW2_LW_in  EW2_LW_out  EW2_SW_in  EW2_SW_out  \
# Date
# 2013-08-01 00:00:00  423.277293  448.281793          0           0
# 2013-08-01 01:00:00  415.566593  445.204426          0           0
# 2013-08-01 02:00:00  415.347609  444.251359          0           0
# 2013-08-01 03:00:00  406.711127  440.735210          0           0
# 2013-08-01 04:00:00  414.522285  439.627452          0           0
#
#                       EW3_LW_in  EW3_LW_out  \
# Date
# 2013-08-01 00:00:00  420.386871  443.596871
# 2013-08-01 01:00:00         NaN         NaN
# ...

# %%
df_diurn=df.loc['20130801':'20130901']
#cc=[n for n in df_diurn.columns if ('EW3' not in n and 'WW3' not in n)]
#df_diurn=df_diurn[cc]
df_diurn.head()
df_diurn['WMean_LW_in']=df_diurn.filter(regex='_NOCU_LIN_YSU_NOAH_CLIM').filter(regex='LW_in').T.mean()
df_diurn['WMean_HFX']=df_diurn.filter(regex='_NOCU_LIN_YSU_NOAH_CLIM').filter(regex='HFX').T.mean()
df_diurn['WMean_LFX']=df_diurn.filter(regex='_NOCU_LIN_YSU_NOAH_CLIM').filter(regex='LFX').T.mean()
df_diurn['WMean_LW_out']=df_diurn.filter(regex='_NOCU_LIN_YSU_NOAH_CLIM').filter(regex='LW_out').T.mean()
df_diurn['WMean_SW_in']=df_diurn.filter(regex='_NOCU_LIN_YSU_NOAH_CLIM').filter(regex='SW_in').T.mean()
df_diurn['WMean_SW_out']=df_diurn.filter(regex='_NOCU_LIN_YSU_NOAH_CLIM').filter(regex='SW_out').T.mean()
df_diurn['WMean_rad_net']=df_diurn.filter(regex='_NOCU_LIN_YSU_NOAH_CLIM').filter(regex='rad_net').T.mean()
df_diurn['WMean_T']=df_diurn.filter(regex='_NOCU_LIN_YSU_NOAH_CLIM').filter(regex='_T_').T.mean()

df_diurn['EMean_LW_in']=df_diurn.filter(regex='EW').filter(regex='LW_in').T.mean()
df_diurn['EMean_HFX']=df_diurn.filter(regex='EW').filter(regex='HFX').T.mean()
df_diurn['EMean_LFX']=df_diurn.filter(regex='EW').filter(regex='LFX').T.mean()
df_diurn['EMean_LW_out']=df_diurn.filter(regex='EW').filter(regex='LW_out').T.mean()
df_diurn['EMean_SW_in']=df_diurn.filter(regex='EW').filter(regex='SW_in').T.mean()
df_diurn['EMean_SW_out']=df_diurn.filter(regex='EW').filter(regex='SW_out').T.mean()
df_diurn['EMean_rad_net']=df_diurn.filter(regex='EW').filter(regex='rad_net').T.mean()
df_diurn['EMean_T']=df_diurn.filter(regex='EW').filter(regex='_T').T.mean()
# Out:
# -c:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# -c:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# -c:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# -c:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
cc=[n for n in df_diurn.columns if ('EW2' in n and ('SW_in' in n or 'LFX' in n))]
corr_frame=df_diurn[cc]
corr_frame.EW2_LFX[corr_frame.EW2_SW_in<100]=np.NaN
corr_frame.head()
corr_frame.corr(method='pearson')

# %%
df_diurn['hour'] = df_diurn.index
df_diurn['hour'] = df_diurn['hour'].apply(lambda x: x.hour)
dff=df_diurn.groupby(['hour']).describe().unstack()
# Out:
#        EW1_LW_in  EW1_LW_out     EW1_SW_in  EW1_SW_out   EW2_LW_in  \
# hour
# 0     149.285919   38.744793  2.198047e-02    0.116039  223.608409
# 1     210.842106   36.529675  3.774819e-03    0.092026  195.623260
# 2     194.718555   32.814168  1.043970e-03    0.010219  151.229974
# 3     198.758333   30.350228  4.480295e-03    0.023683  147.266192
# 4     200.332930   27.445348  4.948477e-07    0.000547  158.592097
#
#       EW2_LW_out     EW2_SW_in  EW2_SW_out   EW3_LW_in  EW3_LW_out  \
# hour
# 0      41.732306  0.000000e+00    0.000000  168.072425   54.658256
# 1      32.495747  0.000000e+00    0.000000   67.812194   30.313695
# 2      29.839721  8.215796e-05    0.004310   65.949939   36.799000
# 3      22.933943  7.017772e-07    0.000722   67.211285   21.657598
# 4      19.853136  7.214337e-06    0.001249   71.910922   18.632291
#
#                     ...                  WW3_rad_net_NOCU_LIN_YSU_NOAH_CLIM  \
# hour                ...
# ...

# %%
var='SW_in'
fig, (ax0, ax1, ax2) = plt.subplots(ncols=3, figsize=(19,6))
ax0.set_title('Diurnal Profile Sumbrungu', fontsize=14)
ax0.set_ylabel(var, fontsize=14, weight='bold')
ax0.set_xlabel('Time of Day', fontsize=14)
ax0.set_label
ax0.plot(dff.index, dff['EW1_'+var], 'g', linewidth=2.0)
#ax0.set_ylim([20,35])

ax1.set_title('Diurnal Profile Kayoro', fontsize=14)
ax1.set_ylabel(var, fontsize=14, weight='bold')
ax1.set_xlabel('Time of Day', fontsize=14)
ax1.plot(dff.index, dff['EW2_'+var], 'g', linewidth=2.0)
#ax1.set_ylim([20,35])

ax2.set_title('Diurnal Profile Nazinga', fontsize=14)
ax2.set_ylabel(var, fontsize=14, weight='bold')
ax2.set_xlabel('Time of Day', fontsize=14)
ax2.plot(dff.index, dff['EW3_'+var+''], 'g', linewidth=2.0)
#ax2.set_ylim([20,35])
#print  df_diurn['EW1_'+var]['mean']
#print  df_diurn['EW2_'+var]['mean']
#print  df_diurn['EW3_'+var]['mean']

# %%
df_diurn['Date']=df_diurn.index.map(lambda x: x.strftime("%H"))hour
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-3675cb73be59> in <module>()
#       1 df_diurn['Date']=df_diurn.index.map(lambda x: x.strftime("%H"))
#       2 df_diurn = df_diurn.groupby('Date').describe().unstack()
# ----> 3 df_diurn.index = pd.to_datetime(df_diurn.index.astype(str))
#       4 df_diurn.index
#
# /home/klein-c/data/anaconda/lib/python2.7/site-packages/pandas/util/decorators.pyc in wrapper(*args, **kwargs)
#      87                 else:
#      88                     kwargs[new_arg_name] = new_arg_value
# ---> 89             return func(*args, **kwargs)
#      90         return wrapper
#      91     return _deprecate_kwarg
#
# /home/klein-c/data/anaconda/lib/python2.7/site-packages/pandas/tseries/tools.pyc in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, coerce, unit, infer_datetime_format)
# ...

# %%
var='SW_in'
fig, (ax0, ax1, ax2) = plt.subplots(ncols=3, figsize=(19,6))
ax0.set_title('Diurnal Profile Sumbrungu', fontsize=14)
ax0.set_ylabel(var, fontsize=14, weight='bold')
ax0.set_xlabel('Time of Day', fontsize=14)
ax0.set_label
ax0.plot(df_diurn.index, df_diurn['EW1_'+var]['mean'], 'g', linewidth=2.0)
ax0.plot(df_diurn.index, df_diurn['WW1_'+var+'_NOCU_LIN_YSU_NOAH_DYN']['mean'], 'r', linewidth=1.0)
ax0.plot(df_diurn.index, df_diurn['WW1_'+var+'_NOCU_LIN_YSU_NOAH_STATIC']['mean'], 'b', linewidth=1.0)
ax0.plot(df_diurn.index, df_diurn['WW1_'+var+'_NOCU_LIN_YSU_NOAH_TABLE']['mean'], 'y', linewidth=1.0)
ax0.plot(df_diurn.index, df_diurn['WW1_'+var+'_NOCU_LIN_YSU_NOAH_CLIM']['mean'], 'g', linewidth=1.0)
#ax0.set_ylim([20,35])


ax1.set_title('Diurnal Profile Kayoro', fontsize=14)
ax1.set_ylabel(var, fontsize=14, weight='bold')
ax1.set_xlabel('Time of Day', fontsize=14)
ax1.plot(df_diurn.index, df_diurn['EW2_'+var]['mean'], 'g', linewidth=2.0)
ax1.plot(df_diurn.index, df_diurn['WW2_'+var+'_NOCU_LIN_YSU_NOAH_DYN']['mean'], 'r', linewidth=1.0)
ax1.plot(df_diurn.index, df_diurn['WW2_'+var+'_NOCU_LIN_YSU_NOAH_STATIC']['mean'], 'b', linewidth=1.0)
ax1.plot(df_diurn.index, df_diurn['WW2_'+var+'_NOCU_LIN_YSU_NOAH_TABLE']['mean'], 'y', linewidth=1.0)
ax1.plot(df_diurn.index, df_diurn['WW2_'+var+'_NOCU_LIN_YSU_NOAH_CLIM']['mean'], 'g', linewidth=1.0)
#ax1.set_ylim([20,35])

ax2.set_title('Diurnal Profile Nazinga', fontsize=14)
ax2.set_ylabel(var, fontsize=14, weight='bold')
ax2.set_xlabel('Time of Day', fontsize=14)
ax2.plot(df_diurn.index, df_diurn['EW3_'+var+'']['mean'], 'g', linewidth=2.0)
ax2.plot(df_diurn.index, df_diurn['WW3_'+var+'_NOCU_LIN_YSU_NOAH_DYN']['mean'], 'r', linewidth=1.0)
ax2.plot(df_diurn.index, df_diurn['WW3_'+var+'_NOCU_LIN_YSU_NOAH_STATIC']['mean'], 'b', linewidth=1.0)
ax2.plot(df_diurn.index, df_diurn['WW3_'+var+'_NOCU_LIN_YSU_NOAH_TABLE']['mean'], 'y', linewidth=1.0)
ax2.plot(df_diurn.index, df_diurn['WW3_'+var+'_NOCU_LIN_YSU_NOAH_CLIM']['mean'], 'g', linewidth=1.0)
#ax2.set_ylim([20,35])
#print  df_diurn['EW1_'+var]['mean']
#print  df_diurn['EW2_'+var]['mean']
#print  df_diurn['EW3_'+var]['mean']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-843d4f65c698> in <module>()
#       5 ax0.set_xlabel('Time of Day', fontsize=14)
#       6 ax0.set_label
# ----> 7 ax0.plot(df_diurn.index, df_diurn['EW1_'+var]['mean'], 'g', linewidth=2.0)
#       8 ax0.plot(df_diurn.index, df_diurn['WW1_'+var+'_NOCU_LIN_YSU_NOAH_DYN']['mean'], 'r', linewidth=1.0)
#       9 ax0.plot(df_diurn.index, df_diurn['WW1_'+var+'_NOCU_LIN_YSU_NOAH_STATIC']['mean'], 'b', linewidth=1.0)
#
# /home/klein-c/data/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     549     def __getitem__(self, key):
#     550         try:
# --> 551             result = self.index.get_value(self, key)
#     552
#     553             if not np.isscalar(result):
#
# ...

# %%
var='T'
fig, (ax0, ax1, ax2) = plt.subplots(ncols=3, figsize=(19,6))
ax0.set_title('Diurnal Profile Sumbrungu', fontsize=14)
ax0.set_ylabel(var, fontsize=14, weight='bold')
ax0.set_xlabel('Time of Day', fontsize=14)
ax0.set_label
ax0.plot(df_diurn.index, df_diurn['EW1_'+var]['mean'], 'g', linewidth=2.0)
ax0.plot(df_diurn.index, df_diurn['WW1_'+var+'_NOCU_LIN_YSU_NOAH_DYN']['mean'], 'r', linewidth=1.0)
ax0.plot(df_diurn.index, df_diurn['WW1_'+var+'_NOCU_LIN_YSU_NOAH_STATIC']['mean'], 'b', linewidth=1.0)
ax0.plot(df_diurn.index, df_diurn['WW1_'+var+'_NOCU_LIN_YSU_NOAH_CLIM']['mean'], 'y', linewidth=1.0)
#ax0.set_ylim([20,35])


ax1.set_title('Diurnal Profile Kayoro', fontsize=14)
ax1.set_ylabel(var, fontsize=14, weight='bold')
ax1.set_xlabel('Time of Day', fontsize=14)
ax1.plot(df_diurn.index, df_diurn['EMean_'+var]['mean'], 'g', linewidth=2.0)
ax1.plot(df_diurn.index, df_diurn['WW2_'+var+'_NOCU_LIN_YSU_NOAH_DYN']['mean'], 'r', linewidth=1.0)
ax1.plot(df_diurn.index, df_diurn['WW2_'+var+'_NOCU_LIN_YSU_NOAH_STATIC']['mean'], 'b', linewidth=1.0)
ax1.plot(df_diurn.index, df_diurn['WW2_'+var+'_NOCU_LIN_YSU_NOAH_CLIM']['mean'], 'y', linewidth=1.0)
#ax1.set_ylim([20,35])

ax2.set_title('Diurnal Profile Nazinga', fontsize=14)
ax2.set_ylabel(var, fontsize=14, weight='bold')
ax2.set_xlabel('Time of Day', fontsize=14)
ax2.plot(df_diurn.index, df_diurn['EW3_'+var+'']['mean'], 'g', linewidth=2.0)
ax2.plot(df_diurn.index, df_diurn['WW3_'+var+'_NOCU_LIN_YSU_NOAH_DYN']['mean'], 'r', linewidth=1.0)
ax2.plot(df_diurn.index, df_diurn['WW3_'+var+'_NOCU_LIN_YSU_NOAH_STATIC']['mean'], 'b', linewidth=1.0)
ax2.plot(df_diurn.index, df_diurn['WW3_'+var+'_NOCU_LIN_YSU_NOAH_CLIM']['mean'], 'y', linewidth=1.0)
#ax2.set_ylim([20,35])

# %%
df_diurn.head()

# %%
var='W m-2'
fig, (ax0) = plt.subplots(ncols=1, figsize=(7,6))
ax0.set_title('WRF - EC Station Mean', fontsize=16)
ax0.set_ylabel(var, fontsize=15, weight='bold')
ax0.set_xlabel('Time of Day', fontsize=15)
ax0.set_label
lu7, = ax0.plot(df_diurn.index, (((df_diurn['WMean_LFX']['mean'])-(df_diurn['EMean_LFX']['mean']))), 'b',  linewidth=2.0)
lu8, = ax0.plot(df_diurn.index, (((df_diurn['WMean_HFX']['mean'])-(df_diurn['EMean_HFX']['mean']))), 'purple', linewidth=2.0)
lu1, =ax0.plot(df_diurn.index, ((df_diurn['WMean_rad_net']['mean'])-(df_diurn['EMean_rad_net']['mean'])), 'g--', linewidth=2.0)
lu2, =ax0.plot(df_diurn.index, ((df_diurn['WMean_SW_in']['mean'])-(df_diurn['EMean_SW_in']['mean'])), 'r--', linewidth=2.0)
ax0.tick_params(labelsize=15)
ax0.legend([lu7, lu8, lu1, lu2], ['Latent heat flux', 'Sensible heat flux', 'Net radiation', 'Short-wave in'], fontsize=14)                                                                                       
#ax0.set_ylim([20,35])

#var='W m-2'
#ax1.set_title('Difference radiation: WRF-Obs', fontsize=16)
#ax1.set_ylabel(var, fontsize=15, weight='bold')
#ax1.set_xlabel('Time of Day', fontsize=15)
#ax1.tick_params(labelsize=15)
#lu1, =ax1.plot(df_diurn.index, ((df_diurn['WMean_rad_net']['mean'])-(df_diurn['EMean_rad_net']['mean'])), 'g--', linewidth=2.0)
#lu2, =ax1.plot(df_diurn.index, ((df_diurn['WMean_SW_in']['mean'])-(df_diurn['EMean_SW_in']['mean'])), 'red', linewidth=2.0)
#lu3, =ax1.plot(df_diurn.index, ((df_diurn['WMean_SW_out']['mean'])-(df_diurn['EMean_SW_out']['mean'])), 'b--', linewidth=2.0)
#lu4, =ax1.plot(df_diurn.index, ((df_diurn['WMean_LW_in']['mean'])-(df_diurn['EMean_LW_in']['mean'])), 'orange', linewidth=2.0)
#lu5, =ax1.plot(df_diurn.index, ((df_diurn['WMean_LW_out']['mean'])-(df_diurn['EMean_LW_out']['mean'])), 'purple', linewidth=2.0)

#ax1.legend([lu1, lu2, lu3, lu4, lu5], ['Net radiation', 'Short-wave in', 'Short-wave out', 'Long-wave in', 'Long-wave out'], fontsize=14)                                                                                       
fig.savefig('/home/klein-c/data/WRF_LOCAL/plots_präsi/cu_all_runs/lsm_grp_2013/diurn2.png', dpi=250)

# %%
var='WS'
fig, (ax0, ax1, ax2) = plt.subplots(ncols=3, figsize=(19,6))
ax0.set_title('Diurnal Profile Sumbrungu', fontsize=14)
ax0.set_ylabel(var, fontsize=14, weight='bold')
ax0.set_xlabel('Time of Day', fontsize=14)
ax0.set_label
ax0.plot(df_diurn.index, df_diurn['EW1_'+var]['mean'], 'g', linewidth=2.0)
ax0.plot(df_diurn.index, df_diurn['WW1_'+var+'_NOCU_LIN_YSU_NOAH_CLIM']['mean'], 'r', linewidth=1.0)
ax0.plot(df_diurn.index, df_diurn['WW1_'+var+'_NOCU_LIN_YSU_NOAH_STATIC']['mean'], 'b', linewidth=1.0)
ax0.plot(df_diurn.index, df_diurn['WW1_'+var+'_NOCU_LIN_YSU_NOAH_TABLE']['mean'], 'y', linewidth=1.0)
#ax0.set_ylim([20,35])


ax1.set_title('Diurnal Profile Kayoro', fontsize=14)
ax1.set_ylabel(var, fontsize=14, weight='bold')
ax1.set_xlabel('Time of Day', fontsize=14)
ax1.plot(df_diurn.index, df_diurn['EW2_'+var]['mean'], 'g', linewidth=2.0)
ax1.plot(df_diurn.index, df_diurn['WW2_'+var+'_NOCU_LIN_YSU_NOAH_DYN']['mean'], 'r', linewidth=1.0)
ax1.plot(df_diurn.index, df_diurn['WW2_LW_out_NOCU_LIN_YSU_NOAH_CLIM']['mean'], 'b', linewidth=1.0)
ax1.plot(df_diurn.index, df_diurn['WW2_'+var+'_NOCU_LIN_YSU_NOAH_CLIM']['mean'], 'y', linewidth=1.0)
#ax1.set_ylim([20,35])

ax2.set_title('Diurnal Profile Nazinga', fontsize=14)
ax2.set_ylabel(var, fontsize=14, weight='bold')
ax2.set_xlabel('Time of Day', fontsize=14)
ax2.plot(df_diurn.index, df_diurn['EW3_'+var+'']['mean'], 'g', linewidth=2.0)
ax2.plot(df_diurn.index, df_diurn['WW3_'+var+'_NOCU_LIN_YSU_NOAH_DYN']['mean'], 'r', linewidth=1.0)
ax2.plot(df_diurn.index, df_diurn['WW3_'+var+'_NOCU_LIN_YSU_NOAH_STATIC']['mean'], 'b', linewidth=1.0)
ax2.plot(df_diurn.index, df_diurn['WW3_'+var+'_NOCU_LIN_YSU_NOAH_TABLE']['mean'], 'y', linewidth=1.0)
#ax2.set_ylim([20,35])

# %%
var='VWC'
fig, (ax0, ax1, ax2) = plt.subplots(ncols=3, figsize=(19,6))
ax0.set_title('Diurnal Profile Sumbrungu', fontsize=14)
ax0.set_ylabel(var, fontsize=14, weight='bold')
ax0.set_xlabel('Time of Day', fontsize=14)
ax0.set_label
ax0.plot(df_diurn.index, df_diurn['EW1_'+var]['mean'], 'r', linewidth=2.0)
ax0.plot(df_diurn.index, df_diurn['EW2_'+var]['mean'], 'b', linewidth=2.0)
ax0.plot(df_diurn.index, df_diurn['EW3_'+var]['mean'], 'g', linewidth=2.0)


ax0.set_ylim([0,0.3])

# %%
var='LFX'
fig, (ax0, ax1, ax2) = plt.subplots(ncols=3, figsize=(19,6))
ax0.set_title('Diurnal Profile Sumbrungu', fontsize=14)
ax0.set_ylabel(var, fontsize=14, weight='bold')
ax0.set_xlabel('Time of Day', fontsize=14)
ax0.set_label
#ax0.plot(df_diurn.index, ((df_diurn['WMean_'+var]['mean'])-(df_diurn['EMean_'+var]['mean'])), 'r', linewidth=2.0)
ax0.plot(df_diurn.index, df_diurn['WMean_'+var]['mean'], 'b', linewidth=2.0)
ax0.plot(df_diurn.index, df_diurn['EMean_'+var]['mean'], 'r', linewidth=2.0)
ax0.plot(df_diurn.index, df_diurn['EMean_HFX']['mean'], 'g', linewidth=2.0)
ax0.plot(df_diurn.index, df_diurn['WMean_HFX']['mean'], 'y', linewidth=2.0)

# %%
add.head()

# %%
df[df>30].loc['20130818':'20130831'].filter(regex='NOAH').filter(regex='LFX').hist(bins=20)

# %%
df[df>30].loc['20130818':'20130831'].filter(regex='EW').filter(regex='LFX').hist(bins=20)
