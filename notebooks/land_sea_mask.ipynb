# %%
import salem
import xarray as xr
from utils import constants as cnst
from utils import u_plot as uplot, u_darrays as uda, u_met
import numpy as np

# %%
cd ..
# Out:
# /home/ck/pythonWorkspace/proj_CEH

# %%
shdf = salem.read_shapefile(salem.get_demo_file('ne_50m_ocean.shp'))

# %%
era = '/home/ck/DIR/mymachine/cores_fromMeteosat/cores/coresPower_MFG_-40_700km2_-50points_dominant_1982_10.nc'

# %%
ds = xr.open_dataset(era)
#ds = uda.flip_lat(ds)

# %%
ds = ds['tir'].max('time')

# %%
plt.figure(figsize=(13,7))
plt.pcolormesh(ds)
plt.colorbar()

# %%
grid = ds.salem.grid

# %%
roi = grid.region_of_interest(shape=shdf)

# %%
plt.figure(figsize=(13,7))
plt.pcolormesh(roi)
plt.colorbar()

# %%
out = ds.copy()

# %%
out.name = 'LSMASK'
out.values = roi

# %%
out.plot.pcolormesh()

# %%
out.to_netcdf()
