# %%
from utils import u_time as ut
from eod import read_eod as re
import salem
import numpy as np
from scipy.ndimage.measurements import label 
import pyproj
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from scipy.interpolate import griddata
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pylab as pylab
import cartopy.feature as cfeature
import cleo
pylab.rcParams['figure.figsize'] = 20., 12.
# %matplotlib inline

# %%
trmm_folder='/users/global/cornkle/data/OBS/TRMM/trmm_swaths_WA'
msg_folder='/users/global/cornkle/data/OBS/meteosat_SA15'

# %%
m=re.msg(msg_folder)

# %%
t=re.trmm(trmm_folder, yrange=range(2008, 2009), llbox=[-10, 10, 10, 20])

# %%
td=t.getDData(2008, 6, 28, 17, 26)
# Out:
# 2008
# Ind: [1]

# %%
d1=m.getData(y=2008, m=6, d=28, h=17, mi=30)

# %%
d1[d1>-20]=0

# %%
labels, numL = label(d1)

# %%
ax = plt.axes(projection=ccrs.PlateCarree())

plt.contourf(m.lon, m.lat, labels,levels=np.arange(0,10,1), transform=ccrs.PlateCarree())

ax.coastlines()
cbar=plt.colorbar()

# %%
inds = np.where(labels == 6)
              
# cut a box for every single blob from msg - get min max lat lon of the blob
latmax, latmin = m.lat[inds].max() , m.lat[inds].min()
lonmax, lonmin = m.lon[inds].max() , m.lon[inds].min()
td = t.getDData(2008, 6, 28, 17, 26, udcut=[latmin-0.1, latmax+0.1])
d1 = m.getData(y=2008, m=6, d=28, h=17, mi=30, llbox=[lonmin-0.1, lonmax+0.1, latmin-0.1, latmax+0.1])
# Out:
# 2008
# Ind: [1]

# %%
m.boxlat.shape
# Out:
# (181, 313)

# %%
ax = plt.axes(projection=ccrs.PlateCarree())

plt.contourf(t.lon, t.lat, td,levels=np.arange(0,10,1), transform=ccrs.PlateCarree())

ax.coastlines()
cbar=plt.colorbar()

# %%
proj = pyproj.Proj('+proj=merc +lat_0=0. +lon_0=0.')
# Transform lon, lats to the mercator projection
x, y = pyproj.transform(salem.wgs84, proj, m.boxlon, m.boxlat)
# take the min and max
xmax, xmin = np.max(x), np.min(x)
ymax, ymin = np.max(y), np.min(y)
# Count the number of pixels
dx = 5000
nx, r = divmod(xmax - xmin, dx)
ny, r = divmod(ymax - ymin, dx)
# Here one could add + 1 to be sure that the last pixel is always included
grid = salem.Grid(nxny=(nx+10, ny+10), dxdy=(dx, dx), ll_corner=(xmin-15000, ymin-15000), proj=proj)

# %%
# cleo map
cm = cleo.Map(grid)
cm.visualize()

# %%
xi, yi = grid.ij_coordinates
lon, lat = grid.ll_coordinates

# Transform lons, lats to grid
xm, ym = grid.transform(m.boxlon.flatten(), m.boxlat.flatten(), crs=salem.wgs84)
xt, yt = grid.transform(t.lon.flatten(), t.lat.flatten(), crs=salem.wgs84)
        
# Convert for griddata input 
mpoints = np.array((ym, xm)).T
tpoints = np.array((yt, xt)).T
inter = np.array((np.ravel(yi), np.ravel(xi))).T

# %%
# Out:
# (56653, 2)

# %%
# Interpolate using delaunay triangularization 
outm = griddata(mpoints, d1.flatten(), inter, method='linear')
outm = outm.reshape((grid.ny, grid.nx))
        
# Interpolate using delaunay triangularization 
outt = griddata(tpoints, td.flatten(), inter, method='linear')
outt = outt.reshape((grid.ny, grid.nx))

# %%
# reset map just in case
cm.set_data()
cm.set_cmap()
cm.set_geometry()
# show the data
cm.set_cmap(plt.cm.RdYlBu_r)
cm.set_nlevels(256)
cm.set_data(outm)
cm.visualize()

# %%
# reset map just in case
cm.set_data()
cm.set_cmap()
cm.set_geometry()
# show the data
cm.set_cmap(plt.cm.RdYlBu_r)
cm.set_nlevels(256)
cm.set_data(outt)
cm.visualize()

# %%
tmask = np.isfinite(outt)
mmask = np.isfinite(outm)
mask2 = np.isfinite(outm[tmask])

print(sum(mmask.flatten())*0.3)
print(sum(mask2.flatten()))
# Out:
# 5367.0
# 7257

# %%
from scipy import stats

# %%
plt.plot(outt[mask][mask2])

# %%
plt.plot(outm[mask][mask2])

# %%
stats.pearsonr(outt[mask][mask2],outm[mask][mask2])
# Out:
# (0.34725306358895197, 5.9224648943475136e-09)

# %%
from skimage.feature import match_template

# %%
tnan=np.where(np.isnan(outt))
mnan=np.where(np.isnan(outm))
mnan
# Out:
# (array([  0,   0,   0, ..., 119, 119, 119]),
#  array([  0,   1,   2, ..., 193, 194, 195]))

# %%
outt[tnan]=-10**-5
outm[mnan]=30

# %%
corr2 = match_template(outm, outt[5:-5, 5:-5])
y,x = np.unravel_index(np.argmin(corr2), corr2.shape)
print(x,y)
# Out:
# 2 7

# %%
plt.pcolormesh(corr2)
plt.colorbar()

# %%
a = np.array([2,3,4,1,5,6,7,5,8,9,6,3,4,5,7,6,8,9]).reshape((2,3,3))

# %%
a
# Out:
# array([[[2, 3, 4],
#         [1, 5, 6],
#         [7, 5, 8]],
#
#        [[9, 6, 3],
#         [4, 5, 7],
#         [6, 8, 9]]])
