# %%
"""
Copyright (C) 2014 John Evans

This example code illustrates how to access and visualize an LP DAAC MOD13C2
v6 HDF-EOS2 Grid file in Python.

If you have any questions, suggestions, or comments on this example, please use
the HDF-EOS Forum (http://hdfeos.org/forums).  If you would like to see an
example of any other NASA HDF/HDF-EOS data product that is not listed in the
HDF-EOS Comprehensive Examples page (http://hdfeos.org/zoo), feel free to
contact us at eoshelp@hdfgroup.org or post it at the HDF-EOS Forum
(http://hdfeos.org/forums).

Usage:  save this script and run

    $python MOD13C2.A2007001.006.2015161222701.hdf.py

The HDF file must be in your current working directory.

Tested under: Python 2.7.14 :: Anaconda custom (64-bit)
Last updated: 2018-04-13
"""

import os
import re

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from pyhdf.SD import SD, SDC
import cartopy.crs as ccrs
import xarray as xr
import ipdb
import datetime
import glob
import os
import pandas as pd

# %%
# FILE_NAME = '/media/ck/Elements/global/MODIS_LST/MOD11C1.A2021216.006.2021221195429.hdf'
# #FILE_NAME = 'MOD13C2.A2007001.006.2015161222701.hdf'

# # Identify the data field.
# DATAFIELD_NAME = 'CMG 0.05 Deg Daily LST'

# hdf = SD(FILE_NAME, SDC.READ)

# # Read dataset.
# data2D = hdf.select(DATAFIELD_NAME)
# data = data2D[:,:].astype(np.double)

# # Read attributes.
# attrs = data2D.attributes(full=1)
# lna=attrs["long_name"]
# long_name = lna[0]
# vra=attrs["valid_range"]
# valid_range = vra[0]
# aoa=attrs["add_offset"]
# add_offset = aoa[0]
# fva=attrs["_FillValue"]
# _FillValue = fva[0]
# sfa=attrs["scale_factor"]
# scale_factor = sfa[0]        
# ua=attrs["units"]
# units = ua[0]

# # Handle fill value.
# invalid = data == _FillValue
# invalid = np.logical_or(invalid, data < valid_range[0])
# invalid = np.logical_or(invalid, data > valid_range[1])
# data[invalid] = np.nan

# # Apply scale factor and offset.
# data = (data - add_offset) / scale_factor 
# data = np.ma.masked_array(data, np.isnan(data))
        
# # Normally we would use the grid metadata to reconstruct the grid, but
# # the grid metadata is incorrect in this case, specifically the upper left
# # and lower right coordinates of the grid.  We'll construct the grid
# # manually, taking into account the fact that we're going to subset the
# # data by a factor of 10 (the grid size is 3600 x 7200).
# x = np.linspace(-180, 180, 7200)
# y = np.linspace(90, -90, 3600)
# lon, lat = np.meshgrid(x, y)

# %%
def read_modis_monthly(FILE_NAME, dnames=None, save=False):
    # Identify the data field.
    
#     fields = ['CMG 0.05 Deg Monthly NDVI']
#     DATAFIELD_NAME = 'CMG 0.05 Deg Monthly NDVI'
    print('Doing ',FILE_NAME)

    out = FILE_NAME.replace('.hdf', '.nc')
    if os.path.isfile(out):
        print('File exists, return')
        return

    hdf = SD(FILE_NAME, SDC.READ)
    
    if dnames is None:
        dnames = hdf.datasets().keys()
    
    ds = xr.Dataset()
    
    # Normally we would use the grid metadata to reconstruct the grid, but
    # the grid metadata is incorrect in this case, specifically the upper left
    # and lower right coordinates of the grid.  We'll construct the grid
    # manually, taking into account the fact that we're going to subset the
    # data by a factor of 10 (the grid size is 3600 x 7200).
    lon = np.linspace(-180, 180, 7200)
    lat = np.linspace(90, -90, 3600)
    #lon, lat = np.meshgrid(x, y)
    
    split_date = FILE_NAME.split('.')[1]
    year = split_date[1:5]
    
    date = datetime.datetime(int(year), 1, 1) + pd.Timedelta(str(int(split_date[5:8]) - 1)+' days')
    
    #ipdb.set_trace()
    
    for DATAFIELD_NAME in dnames:

        # Read dataset.
        data2D = hdf.select(DATAFIELD_NAME)
        data = data2D[:,:].astype(np.float)

        # Read attributes.
        attrs = data2D.attributes(full=1)
        lna=attrs["long_name"]
        long_name = lna[0]
        vra=attrs["valid_range"]
        valid_range = vra[0]
        try:
            aoa=attrs["add_offset"]
            add_offset = aoa[0]
        except:
            add_offset = 0
            pass
        fva=attrs["_FillValue"]
        _FillValue = fva[0]
        try:
            sfa=attrs["scale_factor"]
            scale_factor = sfa[0]
        except:
            pass
        #ua=attrs["units"]
        #units = ua[0]

        # Handle fill value.
        invalid = data == _FillValue
        invalid = np.logical_or(invalid, data < valid_range[0])
        invalid = np.logical_or(invalid, data > valid_range[1])
        data[invalid] = np.nan

        # Apply scale factor and offset.
        
        data = (data - add_offset) * scale_factor 
        #ipdb.set_trace()
        #data = np.ma.masked_array(data, np.isnan(data))
        
        da = xr.DataArray(data[None, ...], coords={'time': np.array([date]),
                                             'lat': lat,
                                             'lon': lon},
                      dims=['time', 'lat', 'lon'])  # .isel(time=0)
        
        ds[DATAFIELD_NAME] = da
        
    if save:
        comp = dict(zlib=True, complevel=5)
        encoding = {var: comp for var in ds.data_vars}
        
        
        ds.to_netcdf(path=out, mode='w', encoding=encoding, format='NETCDF4')
        return
        
    return ds

# %%
FILE_NAME = '/media/ck/Elements/global/MODIS_LST/MOD11C1.A2021216.006.2021221195429.hdf'
test = read_modis_monthly(FILE_NAME, dnames=['Day_view_time'])   #['CMG 0.05 Deg Monthly NDVI']
# Out:
# Doing  /media/ck/Elements/global/MODIS_LST/MOD11C1.A2021216.006.2021221195429.hdf

# %%
files = glob.glob( '/media/ck/Elements/global/NDVI_monthly/*.hdf')

# %%
for f in files:
    test = read_modis_monthly(f, dnames=['CMG 0.05 Deg Monthly NDVI'], save=True)
# Out:
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2000032.006.2015147122546.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2000061.006.2015147114337.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2000092.006.2015147120158.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2000122.006.2015147120137.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2000153.006.2015147120153.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2000183.006.2015147120151.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2000214.006.2015147114343.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2000245.006.2015147121321.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2020122.006.2020162030221.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2020153.006.2020197064848.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2020183.006.2020226020621.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2020214.006.2020262001123.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2020245.006.2020291081200.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2020275.006.2020322024821.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2020306.006.2020338063032.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2020336.006.2021003231700.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2021001.006.2021034002320.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2021032.006.2021067223331.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2021060.006.2021098052739.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2019091.006.2019130010441.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2019121.006.2019162015102.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2019152.006.2019194012026.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2019182.006.2019226025634.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2019213.006.2019262180106.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2019244.006.2019290005024.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2019274.006.2019306014711.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2019305.006.2019338005234.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2019335.006.2020004224207.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2020001.006.2020034154921.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2020032.006.2020066025319.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2020061.006.2020100221115.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2018060.006.2018098013759.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2018091.006.2018130005500.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2018121.006.2018162013844.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2018152.006.2018197110344.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2018182.006.2018227133548.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2018213.006.2018258020231.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2018244.006.2018295115447.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2018274.006.2018313120732.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2018305.006.2018338091253.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2018335.006.2019032140048.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2019001.006.2019038102624.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2019032.006.2019084102449.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2017032.006.2017066084614.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2017060.006.2017104132757.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2017091.006.2017131094709.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2017121.006.2017164073135.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2017152.006.2017194074009.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2017182.006.2017234122104.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2017213.006.2017262102806.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2
hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2006121.006.2015161164239.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2006152.006.2015161175917.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2006182.006.2015161193917.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2006213.006.2015161200559.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2006244.006.2015161210216.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2006274.006.2015161210513.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2006305.006.2015161213847.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2006335.006.2015161221254.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2007001.006.2015161222701.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2007032.006.2015161225658.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2007060.006.2015161233551.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2005060.006.2015156014744.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2005091.006.2015156014741.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2005121.006.2015156022305.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2005152.006.2015156022336.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2005182.006.2015156022314.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2005213.006.2015156014737.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2005244.006.2015156022306.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2005274.006.2015156022515.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2005305.006.2015156022534.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2005335.006.2015156014724.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2006001.006.2015161114157.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2006032.006.2015161122801.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2004032.006.2015154131549.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2004061.006.2015154131621.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2004092.006.2015154132334.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2004122.006.2015154132328.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2004153.006.2015154134745.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2004183.006.2015154135515.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2004214.006.2015154140307.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2004245.006.2015154141908.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2004275.006.2015154144420.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2004306.006.2015154144608.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2004336.006.2015162105701.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2005001.006.2015156004627.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2003001.006.2015154065812.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2003032.006.2015156103445.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2003060.006.2015156194629.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2003091.006.2015156195229.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2003121.006.2015159103123.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2003152.006.2015159103544.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2003182.006.2015159103815.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2003213.006.2015154095214.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2003244.006.2015153105815.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2003274.006.2015153105812.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2003305.006.2015153105811.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2003335.006.2015153105803.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2001335.006.2015147121957.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2002001.006.2015147122555.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2002032.006.2015147122617.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2002060.006.2015147135754.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2002091.006.2015148001941.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2002121.006.2015148120148.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2002152.006.2015149022908.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2002182.006.2015149202909.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2002213.006.2015150220937.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2002244.006.2015151101658.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2002274.006.2015152043706.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2002305.006.2015152211339.hdf
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2000306.006.2015147121634.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2000336.006.2015147121623.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2001001.006.2015147121314.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2001032.006.2015147121749.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2001060.006.2015147121248.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2001091.006.2015147121843.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2001121.006.2015147121839.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2001152.006.2015147121827.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2001182.006.2015147121942.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2001213.006.2015147122524.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2001244.006.2015147122526.hdf
# File exists, return
# Doing  /media/ck/Elements/global/NDVI_monthly/MOD13C2.A2001274.006.2015147121304.hdf
# File exists, return

# %%
((test['Day_view_time'].isel(time=0))).plot.contourf(levels=np.arange(0,24), cmap='jet')

# %%
night = '/media/ck/Elements/global/AMSR2/daily/10km/night/LPRM-AMSR2_L3_DS_D_SOILM3_V001_20120707003245.nc4.nc4'
day = '/media/ck/Elements/global/AMSR2/daily/10km/day/LPRM-AMSR2_L3_DS_A_SOILM3_V001_20120710001401.nc4.nc4'
def get_time(filename):
    amsr = xr.open_dataset(filename)
    times = amsr['scantime']
    times_flat = times.values.flat
    real_time = []
    real_hours = []
    for tf in times_flat:
        if np.isnat(tf):
            real_time.append("NaT")
            real_hours.append(-999)
        else:
           # ipdb.set_trace()
            real_time.append(pd.to_datetime(tf))
            real_hours.append(pd.to_datetime(tf).hour)
    real_hours = np.array(real_hours)
    real_hours.shape = times.shape
    return real_hours

# %%
nighthours = get_time(night)

# %%
dayhours = get_time(day)

# %%
f = plt.figure(figsize=(9,5), dpi=200)
plt.contourf(dayhours.T[::-1,:], levels=np.arange(0,24))
plt.colorbar()
f.savefig('/media/ck/Elements/global/AMSR2/day_hours.jpg')

# %%
f = plt.figure(figsize=(9,5), dpi=200)
plt.contourf(nighthours.T[::-1,:], levels=np.arange(0,24))
plt.colorbar()
f.savefig('/media/ck/Elements/global/AMSR2/night_hours.jpg')

# %%
a[::-1]
# Out:
# array([9, 8, 7, 6, 5, 4, 3, 2, 1, 0])
