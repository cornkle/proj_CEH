# %%
import numpy as np
import matplotlib.pyplot as plt
import shapely.geometry as shpg
from scipy.interpolate import griddata
import pyproj
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pylab as pylab
from eod import msg as msg
pylab.rcParams['figure.figsize'] = 20., 12.
# %matplotlib inline
import pyproj
import cleo
import salem
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-141-2660837c89c3> in <module>()
#      11 get_ipython().magic(u'matplotlib inline')
#      12 import pyproj
# ---> 13 import cleo
#      14 import salem
#
# /users/global/cornkle/data/pythonWorkspace/proj_CEH/cleo/__init__.py in <module>()
#      25 # API
#      26 from cleo.colors import get_cm
# ---> 27 from cleo.graphics import DataLevels
#      28 from cleo.graphics import Map
#
# /users/global/cornkle/data/pythonWorkspace/proj_CEH/cleo/graphics.py in <module>()
#      18 from mpl_toolkits.axes_grid1 import make_axes_locatable
#      19 from shapely.geometry import MultiPoint
# ---> 20 from descartes.patch import PolygonPatch
#      21 from matplotlib.collections import PatchCollection, LineCollection
#      22 import salem
#
# ImportError: No module named descartes.patch

# %%
HOD=range(24)   # hours of day
CFAC=-781648343
LFAC=-781648343
COFF=1856
LOFF=1856
YRANGE=range(2004,2014)

tpath= "/users/global/cornkle/data/OBS/TRMM/trmm_swaths_WA/"
tf=msg.extract_TRMMfile(tpath, hod=HOD, yrange=YRANGE, mtresh=1)
tf.keys()
print(len(tf['fpath']))
# Out:
# 1064

# %%
dmsg, dtrmm=msg.quickreadTrmmMSG(tf, nb=0)

# %%
tnb=np.array(range(len(tf['fpath'])))
maxs=[]
for tp in tnb:
    dmsg, dtrmm=msg.quickreadTrmmMSG(tf, nb=tp)
    td=dtrmm['pcp'].mean().max()
    maxs.append(td)
sort_max, sort_nbs = zip(*sorted(zip(maxs, tnb), reverse=True))

# %%
print(sort_max[0:10])
print(sort_nbs[0:10])
# Out:
# (1.4574619424317103, 1.2604372566636788, 0.94629474740715469, 0.78822898650985707, 0.75571597933779167, 0.72896770358628826, 0.71934199688844214, 0.70978014394163236, 0.70650733977801272, 0.70113297988234335)
# (334, 490, 845, 437, 730, 696, 841, 79, 992, 288)

# %%
top5=sort_nbs[0:5]
print(top5)
# Out:
# (334, 490, 845, 437, 730)

# %%
NB=top5[2]
mi=tf['tmins'][NB]
dmsg, dtrmm=msg.quickreadTrmmMSG(tf, nb=NB)
mlat=dmsg['lats']
mlon=dmsg['lons']
md=dmsg['t']
tlat=dtrmm['lats']
tlon=dtrmm['lons']
td=dtrmm['pcp']
print(mi)
mlon.flatten()
# Out:
# 27
# array([-16.78334045, -16.75442505, -16.72542572, ...,  32.65229416,
#         32.69068527,  32.72912598], dtype=float32)

# %%
dy1=0
dy2=300
dx1=0
dx2=400
tdy1=30
tdy2=400

ax = plt.axes(projection=ccrs.PlateCarree())
plt.contourf(tlon[tdy1:tdy2, :], tlat[tdy1:tdy2, :], td[tdy1:tdy2, :],levels=np.arange(0,100, 0.5), transform=ccrs.PlateCarree(), cmap='Pastel1')
plt.contourf(mlon[dy1:dy2, dx1:dx2], mlat[dy1:dy2, dx1:dx2], md[dy1:dy2, dx1:dx2], levels=np.arange(-80,-30,1), transform=ccrs.PlateCarree())
cbar=plt.colorbar()
cbar.set_label('T (degC)', rotation=270, labelpad=+11)
plt.contourf(tlon[tdy1:tdy2, :], tlat[tdy1:tdy2, :], td[tdy1:tdy2, :],levels=np.arange(5,70, 0.5), transform=ccrs.PlateCarree())

ax.coastlines()
cbar=plt.colorbar()
cbar.set_label('PCP (mm h-1)', rotation=270, labelpad=+11)
#plt.savefig('/users/global/cornkle/'+str(NB)+'_msgtd0_p_'+str(mi)+'.pdf')

# %%
# make a salem grid
proj = pyproj.Proj('+proj=merc +lat_0=0. +lon_0=0.')
grid = salem.Grid(nxny=(300, 300), dxdy=(5000, 5000), ll_corner=(-1600000., -45000.), proj=proj)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-64873101fac4> in <module>()
#       1 # make a salem grid
# ----> 2 proj = pyproj.Proj('+proj=merc +lat_0=0. +lon_0=0.')
#       3 grid = salem.Grid(nxny=(300, 300), dxdy=(5000, 5000), ll_corner=(-1600000., -45000.), proj=proj)
#
# NameError: name 'pyproj' is not defined

# %%
# Transform lons, lats to grid
xm, ym = grid.transform(mlon[dy1:dy2, dx1:dx2].flatten(), mlat[dy1:dy2, dx1:dx2].flatten(), crs=salem.wgs84)
xt, yt = grid.transform(tlon[tdy1:tdy2, :].flatten(), tlat[tdy1:tdy2, :].flatten(), crs=salem.wgs84)

# %%
cm = cleo.Map(grid)

# %%
# Grid x, y
xi, yi = grid.ij_coordinates

# %%
# Convert for griddata input 
mpoints = np.array((ym, xm)).T
tpoints = np.array((yt, xt)).T
inter = np.array((np.ravel(yi), np.ravel(xi))).T

# %%
# Interpolate using delaunay triangularization 
outm = griddata(mpoints, md[dy1:dy2, dx1:dx2].flatten(), inter, method='linear')
outm = outm.reshape((grid.ny, grid.nx))

# %%
mpoints.shape
# Out:
# (120000, 2)

# %%
# Interpolate using delaunay triangularization 
outt = griddata(tpoints, td[tdy1:tdy2, :].flatten(), inter, method='linear')
outt = outt.reshape((grid.ny, grid.nx))

# %%
plt.contourf(yi.T, xi.T, outm,levels=np.arange(-80,-30,1))
plt.contourf(yi.T, xi.T, outt, levels=np.arange(5,70, 0.5))
plt.savefig('/users/global/cornkle/'+str(NB)+'_msgtest_p_'+str(mi)+'.pdf')

# %%
plt.contourf(yi.T, xi.T, outm,levels=np.arange(-80,-30,1))
#plt.contourf(yi.T, xi.T, outt, levels=np.arange(5,70, 0.5))
plt.savefig('/users/global/cornkle/'+str(NB)+'_msgtest_'+str(mi)+'.pdf')
