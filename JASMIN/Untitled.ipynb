# %%
import pdb
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pylab as pylab
import cartopy
import cartopy.crs as ccrs
import pickle as pkl

pylab.rcParams['figure.figsize'] = (50., 50.)
# %matplotlib inline

# %%
cd ..
# Out:
# /home/users/cornkle/pythonWorkspace/proj_CEH

# %%
var = 'lsRain'
hour = '17'

ds = pkl.load(open('/home/users/cornkle/lmcs/cklein/CP_models/MCS_files/'+var+'_timeseries_-10to+10days_'+hour+'.p','rb'))

# %%
rain = np.array(ds['CP4hist']).mean(axis=0)
rain_fut = np.array(ds['CP4fut']).mean(axis=0)

# %%
f = plt.figure(figsize=(9,5), dpi=200)
plt.plot(rain)
plt.plot(rain_fut)

# %%
var = 'sh'
hour = '17'

ds = pkl.load(open('/home/users/cornkle/lmcs/cklein/CP_models/MCS_files/'+var+'_anom_timeseries_-10to+10days_'+hour+'.p','rb'))
rain = np.array(ds['CP4hist']).mean(axis=0)
rain_fut = np.array(ds['CP4fut']).mean(axis=0)
f = plt.figure(figsize=(9,5), dpi=200)
plt.plot(rain)
plt.plot(rain_fut)
